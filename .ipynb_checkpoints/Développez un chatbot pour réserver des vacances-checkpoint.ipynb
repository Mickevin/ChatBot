# %% [markdown]
# # Développez un chatbot pour réserver des vacances
#
# <img src='https://user.oc-static.com/upload/2019/10/24/15719199766568_Capture%20d%E2%80%99e%CC%81cran%202019-10-24%20a%CC%80%2014.14.41.png'>
#
#
# Fly Me est une agence qui propose des voyages clé en main pour les particuliers ou les professionnels.
#
#
# Fly Me a lancé un projet ambitieux de développement d’un chatbot pour aider les utilisateurs à choisir une offre de voyage.
#
# La première étape de ce projet est de construire un MVP qui aidera les employés de Fly Me à réserver facilement un billet d’avion pour leurs vacances.
#
# Comme ce projet est itératif, nous avons limité les fonctionnalités de la V1 du chatbot. La V1 devra pouvoir identifier dans la demande de l’utilisateur les cinq éléments suivants :
#
# Ville de départ
# Ville de destination
# Date aller souhaitée du vol
# Date retour souhaitée du vol
# Budget maximum pour le prix total des billets

# %% [markdown]
# # Observation du jeu de données

# %%
import pandas as pd
import numpy as np
import json

with open('../frames/frames.json') as f:
    df = json.load(f)
    
    
print(f'Le jeu de données contient {len(df)} conversations entre bot & utilisateur')
df = [df[n] for n in range(len(df)) if n !=89 and n !=391]
df[0]
# Out:
# Le jeu de données contient 1369 conversations entre bot & utilisateur
# {'user_id': 'U22HTHYNP',
#  'turns': [{'text': "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700.",
#    'labels': {'acts': [{'args': [{'val': 'book', 'key': 'intent'}],
#       'name': 'inform'},
#      {'args': [{'val': 'Atlantis', 'key': 'dst_city'},
#        {'val': 'Caprica', 'key': 'or_city'},
#        {'val': 'Saturday, August 13, 2016', 'key': 'str_date'},
#        {'val': '8', 'key': 'n_adults'},
#        {'val': '1700', 'key': 'budget'}],
#       'name': 'inform'}],
#     'acts_without_refs': [{'args': [{'val': 'book', 'key': 'intent'}],
#       'name': 'inform'},
#      {'args': [{'val': 'Atlantis', 'key': 'dst_city'},
#        {'val': 'Caprica', 'key': 'or_city'},
#        {'val': 'Saturday, August 13, 2016', 'key': 'str_date'},
#        {'val': '8', 'key': 'n_adults'},
#        {'val': '1700', 'key': 'budget'}],
#       'name': 'inform'}],
#     'active_frame': 1,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'user',
#    'timestamp': 1471272019730.0},
#   {'db': {'result': [[{'trip': {'returning': {'duration': {'hours': 0,
#           'min': 51},
#          'arrival': {'hour': 10,
#           'year': 2016,
#           'day': 24,
#           'min': 51,
#           'month': 8},
#          'departure': {'hour': 10,
#           'year': 2016,
#           'day': 24,
#           'min': 0,
#           'month': 8}},
#         'seat': 'ECONOMY',
#         'leaving': {'duration': {'hours': 0, 'min': 51},
#          'arrival': {'hour': 0,
#           'year': 2016,
#           'day': 16,
#           'min': 51,
#           'month': 8},
#          'departure': {'hour': 0,
#           'year': 2016,
#           'day': 16,
#           'min': 0,
#           'month': 8}},
#         'or_city': 'Porto Alegre',
#         'duration_days': 9},
#        'price': 2118.81,
#        'hotel': {'gst_rating': 7.15,
#         'vicinity': [],
#         'name': 'Scarlet Palms Resort',
#         'country': 'Brazil',
#         'amenities': ['FREE_BREAKFAST', 'FREE_PARKING', 'FREE_WIFI'],
#         'dst_city': 'Goiania',
#         'category': '3.5 star hotel'}},
#       {'trip': {'returning': {'duration': {'hours': 2, 'min': 37},
#          'arrival': {'hour': 12,
#           'year': 2016,
#           'day': 10,
#           'min': 37,
#           'month': 8},
#          'departure': {'hour': 10,
#           'year': 2016,
#           'day': 10,
#           'min': 0,
#           'month': 8}},
#         'seat': 'ECONOMY',
#         'leaving': {'duration': {'hours': 2, 'min': 37},
#          'arrival': {'hour': 0, 'year': 2016, 'day': 4, 'min': 37, 'month': 8},
#          'departure': {'hour': 22,
#           'year': 2016,
#           'day': 3,
#           'min': 0,
#           'month': 8}},
#         'or_city': 'Porto Alegre',
#         'duration_days': 7},
#        'price': 2369.83,
#        'hotel': {'gst_rating': 0,
#         'vicinity': [],
#         'name': 'Sunway Hostel',
#         'country': 'Argentina',
#         'amenities': ['FREE_BREAKFAST', 'FREE_WIFI'],
#         'dst_city': 'Rosario',
#         'category': '2.0 star hotel'}},
#       {'trip': {'returning': {'duration': {'hours': 0, 'min': 51},
#          'arrival': {'hour': 10,
#           'year': 2016,
#           'day': 24,
#           'min': 51,
#           'month': 8},
#          'departure': {'hour': 10,
#           'year': 2016,
#           'day': 24,
#           'min': 0,
#           'month': 8}},
#         'seat': 'BUSINESS',
#         'leaving': {'duration': {'hours': 0, 'min': 51},
#          'arrival': {'hour': 0,
#           'year': 2016,
#           'day': 16,
#           'min': 51,
#           'month': 8},
#          'departure': {'hour': 0,
#           'year': 2016,
#           'day': 16,
#           'min': 0,
#           'month': 8}},
#         'or_city': 'Porto Alegre',
#         'duration_days': 9},
#        'price': 2375.72,
#        'hotel': {'gst_rating': 7.15,
#         'vicinity': [],
#         'name': 'Scarlet Palms Resort',
#         'country': 'Brazil',
#         'amenities': ['FREE_BREAKFAST', 'FREE_PARKING', 'FREE_WIFI'],
#         'dst_city': 'Goiania',
#         'category': '3.5 star hotel'}},
#       {'trip': {'returning': {'duration': {'hours': 1, 'min': 30},
#          'arrival': {'hour': 11,
#           'year': 2016,
#           'day': 1,
#           'min': 30,
#           'month': 9},
#          'departure': {'hour': 10,
#           'year': 2016,
#           'day': 1,
#           'min': 0,
#           'month': 9}},
#         'seat': 'BUSINESS',
#         'leaving': {'duration': {'hours': 1, 'min': 30},
#          'arrival': {'hour': 18,
#           'year': 2016,
#           'day': 19,
#           'min': 30,
#           'month': 8},
#          'departure': {'hour': 17,
#           'year': 2016,
#           'day': 19,
#           'min': 0,
#           'month': 8}},
#         'or_city': 'Porto Alegre',
#         'duration_days': 13},
#        'price': 2492.95,
#        'hotel': {'gst_rating': 0,
#         'vicinity': [],
#         'name': 'Hotel Mundo',
#         'country': 'Brazil',
#         'amenities': ['FREE_BREAKFAST', 'FREE_WIFI', 'FREE_PARKING'],
#         'dst_city': 'Manaus',
#         'category': '2.5 star hotel'}},
#       {'trip': {'returning': {'duration': {'hours': 0, 'min': 51},
#          'arrival': {'hour': 10,
#           'year': 2016,
#           'day': 31,
#           'min': 51,
#           'month': 8},
#          'departure': {'hour': 10,
#           'year': 2016,
#           'day': 31,
#           'min': 0,
#           'month': 8}},
#         'seat': 'ECONOMY',
#         'leaving': {'duration': {'hours': 0, 'min': 51},
#          'arrival': {'hour': 19,
#           'year': 2016,
#           'day': 27,
#           'min': 51,
#           'month': 8},
#          'departure': {'hour': 19,
#           'year': 2016,
#           'day': 27,
#           'min': 0,
#           'month': 8}},
#         'or_city': 'Porto Alegre',
#         'duration_days': 4},
#        'price': 2538.0,
#        'hotel': {'gst_rating': 8.22,
#         'vicinity': [],
#         'name': 'The Glee',
#         'country': 'Brazil',
#         'amenities': ['FREE_BREAKFAST', 'FREE_WIFI'],
#         'dst_city': 'Recife',
#         'category': '4.0 star hotel'}}],
#      [],
#      [],
#      [],
#      [],
#      [],
#      []],
#     'search': [{'ORIGIN_CITY': 'Porto Alegre',
#       'PRICE_MIN': '2000',
#       'NUM_ADULTS': '2',
#       'timestamp': 1471271949.995,
#       'PRICE_MAX': '3000',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'NUM_CHILDREN': '5',
#       'START_TIME': '1470110400000',
#       'MAX_DURATION': 2592000000.0,
#       'DESTINATION_CITY': 'Brazil',
#       'RESULT_LIMIT': '10',
#       'END_TIME': '1472616000000'},
#      {'ORIGIN_CITY': 'Atlantis',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272148.124,
#       'PRICE_MAX': '1700',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': 'NaN',
#       'END_TIME': 'NaN'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MAX': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272189.07,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1470715200000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MAX': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272205.436,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1470715200000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MIN': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272278.72,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1470715200000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MIN': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272454.542,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MIN': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272466.008,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': '1472011200000'}]},
#    'text': 'Hi...I checked a few options for you, and unfortunately, we do not currently have any trips that meet this criteria.  Would you like to book an alternate travel option?',
#    'labels': {'acts': [{'args': [{'val': [{'annotations': [],
#           'frame': 1,
#           'fromrange': False}],
#         'key': 'ref'}],
#       'name': 'no_result'},
#      {'args': [{'key': 'dst_city'}], 'name': 'suggest'},
#      {'args': [], 'name': 'sorry'}],
#     'active_frame': 1,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'wizard',
#    'timestamp': 1471272381399.0},
#   {'text': 'Yes, how about going to Neverland from Caprica on August 13, 2016 for 5 adults. For this trip, my budget would be 1900.',
#    'labels': {'acts': [{'args': [{'val': 'Neverland', 'key': 'dst_city'},
#        {'val': '5', 'key': 'n_adults'},
#        {'val': '1900', 'key': 'budget'},
#        {'val': [{'annotations': [{'val': 'Caprica', 'key': 'or_city'},
#            {'val': 'August 13, 2016', 'key': 'str_date'}],
#           'frame': 1,
#           'fromrange': False}],
#         'key': 'ref'}],
#       'name': 'inform'}],
#     'acts_without_refs': [{'args': [{'val': 'Neverland', 'key': 'dst_city'},
#        {'val': '5', 'key': 'n_adults'},
#        {'val': '1900', 'key': 'budget'},
#        {'val': 'Caprica', 'key': 'or_city'},
#        {'val': 'August 13, 2016', 'key': 'str_date'}],
#       'name': 'inform'}],
#     'active_frame': 2,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1900.0', 'negated': False}],
#        'dst_city': [{'val': 'Neverland', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '5', 'negated': False}]},
#       'frame_id': 2,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'user',
#    'timestamp': 1471272508882.0},
#   {'db': {'result': [[], [], [], [], [], []],
#     'search': [{'ORIGIN_CITY': 'Caprica',
#       'PRICE_MIN': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272454.542,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MIN': '1700',
#       'NUM_ADULTS': '8',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272466.008,
#       'DESTINATION_CITY': 'Atlantis',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MAX': '1900',
#       'NUM_ADULTS': '5',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272562.484,
#       'DESTINATION_CITY': 'Neverland',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'PRICE_MAX': '1900',
#       'NUM_ADULTS': '5',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272571.739,
#       'DESTINATION_CITY': 'Neverland',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': '1472011200000'},
#      {'ORIGIN_CITY': 'Caprica',
#       'NUM_ADULTS': '5',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272625.733,
#       'DESTINATION_CITY': 'Neverland',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': 'NaN'},
#      {'ORIGIN_CITY': 'Caprica',
#       'NUM_ADULTS': '5',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272628.27,
#       'DESTINATION_CITY': 'Neverland',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': 'NaN'}]},
#    'text': 'I checked the availability for this date and there were no trips available.  Would you like to select some alternate dates?',
#    'labels': {'acts': [{'args': [{'val': [{'annotations': [{'val': None,
#             'key': 'str_date'}],
#           'frame': 2,
#           'fromrange': False}],
#         'key': 'ref'}],
#       'name': 'no_result'},
#      {'args': [{'key': 'str_date'}, {'key': 'end_date'}], 'name': 'suggest'}],
#     'active_frame': 2,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1900.0', 'negated': False}],
#        'dst_city': [{'val': 'Neverland', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '5', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 2,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'wizard',
#    'timestamp': 1471272800073.0},
#   {'text': 'I have no flexibility for dates... but I can leave from Atlantis rather than Caprica. How about that?',
#    'labels': {'acts': [{'args': [{'val': False, 'key': 'flex'}],
#       'name': 'inform'},
#      {'args': [{'val': 'Atlantis', 'key': 'or_city'}], 'name': 'inform'},
#      {'args': [{'val': [{'annotations': [{'val': 'Caprica', 'key': 'or_city'}],
#           'frame': 1,
#           'fromrange': False}],
#         'key': 'ref'}],
#       'name': 'negate'}],
#     'acts_without_refs': [{'args': [{'val': False, 'key': 'flex'}],
#       'name': 'inform'},
#      {'args': [{'val': 'Atlantis', 'key': 'or_city'}], 'name': 'inform'},
#      {'args': [{'val': 'Caprica', 'key': 'or_city'}], 'name': 'negate'}],
#     'active_frame': 3,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': True}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1900.0', 'negated': False}],
#        'dst_city': [{'val': 'Neverland', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '5', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 2,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'flex': [{'val': False, 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Atlantis', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}]},
#       'frame_id': 3,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'user',
#    'timestamp': 1471272833774.0},
#   {'db': {'result': [[]],
#     'search': [{'ORIGIN_CITY': 'Atlantis',
#       'PRICE_MAX': '1900',
#       'NUM_ADULTS': '5',
#       'RESULT_LIMIT': '10',
#       'timestamp': 1471272866.853,
#       'DESTINATION_CITY': 'Neverland',
#       'NUM_CHILDREN': '',
#       'ARE_DATES_FLEXIBLE': 'true',
#       'START_TIME': '1471060800000',
#       'END_TIME': 'NaN'}]},
#    'text': 'I checked the availability for that date and there were no trips available.  Would you like to select some alternate dates?',
#    'labels': {'acts': [{'args': [{'val': [{'annotations': [{'val': None,
#             'key': 'str_date'}],
#           'frame': 3,
#           'fromrange': False}],
#         'key': 'ref'}],
#       'name': 'no_result'},
#      {'args': [{'key': 'str_date'}, {'key': 'end_date'}], 'name': 'suggest'}],
#     'active_frame': 3,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': True}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1900.0', 'negated': False}],
#        'dst_city': [{'val': 'Neverland', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '5', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 2,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'flex': [{'val': False, 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Atlantis', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 3,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'wizard',
#    'timestamp': 1471273283370},
#   {'text': "I suppose I'll speak with my husband to see if we can choose other dates, and then I'll come back to you.Thanks for your help",
#    'labels': {'acts': [{'args': [], 'name': 'thankyou'}],
#     'acts_without_refs': [{'args': [], 'name': 'thankyou'}],
#     'active_frame': 3,
#     'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': True}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}]},
#       'frame_id': 1,
#       'requests': [],
#       'frame_parent_id': None,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1900.0', 'negated': False}],
#        'dst_city': [{'val': 'Neverland', 'negated': False}],
#        'or_city': [{'val': 'Caprica', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '5', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 2,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []},
#      {'info': {'intent': [{'val': 'book', 'negated': False}],
#        'budget': [{'val': '1700.0', 'negated': False}],
#        'flex': [{'val': False, 'negated': False}],
#        'dst_city': [{'val': 'Atlantis', 'negated': False}],
#        'or_city': [{'val': 'Atlantis', 'negated': False}],
#        'str_date': [{'val': 'august 13', 'negated': False}],
#        'n_adults': [{'val': '8', 'negated': False}],
#        'NO_RESULT': [{'val': True, 'negated': False}]},
#       'frame_id': 3,
#       'requests': [],
#       'frame_parent_id': 1,
#       'binary_questions': [],
#       'compare_requests': []}]},
#    'author': 'user',
#    'timestamp': 1471273458251}],
#  'wizard_id': 'U21DKG18C',
#  'id': 'e2c0fc6c-2134-4891-8353-ef16d8412c9a',
#  'labels': {'userSurveyRating': 4.0, 'wizardSurveyTaskSuccessful': True}}

# %%
df[0].keys()
# Out:
# dict_keys(['user_id', 'turns', 'wizard_id', 'id', 'labels'])

# %%
df[0]['user_id'], df[0]['wizard_id'], df[0]['id'], df[0]['id']
# Out:
# ('U22HTHYNP',
#  'U21DKG18C',
#  'e2c0fc6c-2134-4891-8353-ef16d8412c9a',
#  'e2c0fc6c-2134-4891-8353-ef16d8412c9a')

# %%
df[1]['user_id'], df[1]['wizard_id'], df[1]['id'], df[1]['id']
# Out:
# ('U21E41CQP',
#  'U21DMV0KA',
#  '4a3bfa39-2c22-42c8-8694-32b4e34415e9',
#  '4a3bfa39-2c22-42c8-8694-32b4e34415e9')

# %%
df[0]['turns']
# Out:
# [{'text': "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700.",
#   'labels': {'acts': [{'args': [{'val': 'book', 'key': 'intent'}],
#      'name': 'inform'},
#     {'args': [{'val': 'Atlantis', 'key': 'dst_city'},
#       {'val': 'Caprica', 'key': 'or_city'},
#       {'val': 'Saturday, August 13, 2016', 'key': 'str_date'},
#       {'val': '8', 'key': 'n_adults'},
#       {'val': '1700', 'key': 'budget'}],
#      'name': 'inform'}],
#    'acts_without_refs': [{'args': [{'val': 'book', 'key': 'intent'}],
#      'name': 'inform'},
#     {'args': [{'val': 'Atlantis', 'key': 'dst_city'},
#       {'val': 'Caprica', 'key': 'or_city'},
#       {'val': 'Saturday, August 13, 2016', 'key': 'str_date'},
#       {'val': '8', 'key': 'n_adults'},
#       {'val': '1700', 'key': 'budget'}],
#      'name': 'inform'}],
#    'active_frame': 1,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'user',
#   'timestamp': 1471272019730.0},
#  {'db': {'result': [[{'trip': {'returning': {'duration': {'hours': 0,
#          'min': 51},
#         'arrival': {'hour': 10,
#          'year': 2016,
#          'day': 24,
#          'min': 51,
#          'month': 8},
#         'departure': {'hour': 10,
#          'year': 2016,
#          'day': 24,
#          'min': 0,
#          'month': 8}},
#        'seat': 'ECONOMY',
#        'leaving': {'duration': {'hours': 0, 'min': 51},
#         'arrival': {'hour': 0, 'year': 2016, 'day': 16, 'min': 51, 'month': 8},
#         'departure': {'hour': 0,
#          'year': 2016,
#          'day': 16,
#          'min': 0,
#          'month': 8}},
#        'or_city': 'Porto Alegre',
#        'duration_days': 9},
#       'price': 2118.81,
#       'hotel': {'gst_rating': 7.15,
#        'vicinity': [],
#        'name': 'Scarlet Palms Resort',
#        'country': 'Brazil',
#        'amenities': ['FREE_BREAKFAST', 'FREE_PARKING', 'FREE_WIFI'],
#        'dst_city': 'Goiania',
#        'category': '3.5 star hotel'}},
#      {'trip': {'returning': {'duration': {'hours': 2, 'min': 37},
#         'arrival': {'hour': 12,
#          'year': 2016,
#          'day': 10,
#          'min': 37,
#          'month': 8},
#         'departure': {'hour': 10,
#          'year': 2016,
#          'day': 10,
#          'min': 0,
#          'month': 8}},
#        'seat': 'ECONOMY',
#        'leaving': {'duration': {'hours': 2, 'min': 37},
#         'arrival': {'hour': 0, 'year': 2016, 'day': 4, 'min': 37, 'month': 8},
#         'departure': {'hour': 22,
#          'year': 2016,
#          'day': 3,
#          'min': 0,
#          'month': 8}},
#        'or_city': 'Porto Alegre',
#        'duration_days': 7},
#       'price': 2369.83,
#       'hotel': {'gst_rating': 0,
#        'vicinity': [],
#        'name': 'Sunway Hostel',
#        'country': 'Argentina',
#        'amenities': ['FREE_BREAKFAST', 'FREE_WIFI'],
#        'dst_city': 'Rosario',
#        'category': '2.0 star hotel'}},
#      {'trip': {'returning': {'duration': {'hours': 0, 'min': 51},
#         'arrival': {'hour': 10,
#          'year': 2016,
#          'day': 24,
#          'min': 51,
#          'month': 8},
#         'departure': {'hour': 10,
#          'year': 2016,
#          'day': 24,
#          'min': 0,
#          'month': 8}},
#        'seat': 'BUSINESS',
#        'leaving': {'duration': {'hours': 0, 'min': 51},
#         'arrival': {'hour': 0, 'year': 2016, 'day': 16, 'min': 51, 'month': 8},
#         'departure': {'hour': 0,
#          'year': 2016,
#          'day': 16,
#          'min': 0,
#          'month': 8}},
#        'or_city': 'Porto Alegre',
#        'duration_days': 9},
#       'price': 2375.72,
#       'hotel': {'gst_rating': 7.15,
#        'vicinity': [],
#        'name': 'Scarlet Palms Resort',
#        'country': 'Brazil',
#        'amenities': ['FREE_BREAKFAST', 'FREE_PARKING', 'FREE_WIFI'],
#        'dst_city': 'Goiania',
#        'category': '3.5 star hotel'}},
#      {'trip': {'returning': {'duration': {'hours': 1, 'min': 30},
#         'arrival': {'hour': 11, 'year': 2016, 'day': 1, 'min': 30, 'month': 9},
#         'departure': {'hour': 10,
#          'year': 2016,
#          'day': 1,
#          'min': 0,
#          'month': 9}},
#        'seat': 'BUSINESS',
#        'leaving': {'duration': {'hours': 1, 'min': 30},
#         'arrival': {'hour': 18,
#          'year': 2016,
#          'day': 19,
#          'min': 30,
#          'month': 8},
#         'departure': {'hour': 17,
#          'year': 2016,
#          'day': 19,
#          'min': 0,
#          'month': 8}},
#        'or_city': 'Porto Alegre',
#        'duration_days': 13},
#       'price': 2492.95,
#       'hotel': {'gst_rating': 0,
#        'vicinity': [],
#        'name': 'Hotel Mundo',
#        'country': 'Brazil',
#        'amenities': ['FREE_BREAKFAST', 'FREE_WIFI', 'FREE_PARKING'],
#        'dst_city': 'Manaus',
#        'category': '2.5 star hotel'}},
#      {'trip': {'returning': {'duration': {'hours': 0, 'min': 51},
#         'arrival': {'hour': 10,
#          'year': 2016,
#          'day': 31,
#          'min': 51,
#          'month': 8},
#         'departure': {'hour': 10,
#          'year': 2016,
#          'day': 31,
#          'min': 0,
#          'month': 8}},
#        'seat': 'ECONOMY',
#        'leaving': {'duration': {'hours': 0, 'min': 51},
#         'arrival': {'hour': 19,
#          'year': 2016,
#          'day': 27,
#          'min': 51,
#          'month': 8},
#         'departure': {'hour': 19,
#          'year': 2016,
#          'day': 27,
#          'min': 0,
#          'month': 8}},
#        'or_city': 'Porto Alegre',
#        'duration_days': 4},
#       'price': 2538.0,
#       'hotel': {'gst_rating': 8.22,
#        'vicinity': [],
#        'name': 'The Glee',
#        'country': 'Brazil',
#        'amenities': ['FREE_BREAKFAST', 'FREE_WIFI'],
#        'dst_city': 'Recife',
#        'category': '4.0 star hotel'}}],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []],
#    'search': [{'ORIGIN_CITY': 'Porto Alegre',
#      'PRICE_MIN': '2000',
#      'NUM_ADULTS': '2',
#      'timestamp': 1471271949.995,
#      'PRICE_MAX': '3000',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'NUM_CHILDREN': '5',
#      'START_TIME': '1470110400000',
#      'MAX_DURATION': 2592000000.0,
#      'DESTINATION_CITY': 'Brazil',
#      'RESULT_LIMIT': '10',
#      'END_TIME': '1472616000000'},
#     {'ORIGIN_CITY': 'Atlantis',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272148.124,
#      'PRICE_MAX': '1700',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': 'NaN',
#      'END_TIME': 'NaN'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MAX': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272189.07,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1470715200000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MAX': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272205.436,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1470715200000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MIN': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272278.72,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1470715200000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MIN': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272454.542,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MIN': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272466.008,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': '1472011200000'}]},
#   'text': 'Hi...I checked a few options for you, and unfortunately, we do not currently have any trips that meet this criteria.  Would you like to book an alternate travel option?',
#   'labels': {'acts': [{'args': [{'val': [{'annotations': [],
#          'frame': 1,
#          'fromrange': False}],
#        'key': 'ref'}],
#      'name': 'no_result'},
#     {'args': [{'key': 'dst_city'}], 'name': 'suggest'},
#     {'args': [], 'name': 'sorry'}],
#    'active_frame': 1,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'wizard',
#   'timestamp': 1471272381399.0},
#  {'text': 'Yes, how about going to Neverland from Caprica on August 13, 2016 for 5 adults. For this trip, my budget would be 1900.',
#   'labels': {'acts': [{'args': [{'val': 'Neverland', 'key': 'dst_city'},
#       {'val': '5', 'key': 'n_adults'},
#       {'val': '1900', 'key': 'budget'},
#       {'val': [{'annotations': [{'val': 'Caprica', 'key': 'or_city'},
#           {'val': 'August 13, 2016', 'key': 'str_date'}],
#          'frame': 1,
#          'fromrange': False}],
#        'key': 'ref'}],
#      'name': 'inform'}],
#    'acts_without_refs': [{'args': [{'val': 'Neverland', 'key': 'dst_city'},
#       {'val': '5', 'key': 'n_adults'},
#       {'val': '1900', 'key': 'budget'},
#       {'val': 'Caprica', 'key': 'or_city'},
#       {'val': 'August 13, 2016', 'key': 'str_date'}],
#      'name': 'inform'}],
#    'active_frame': 2,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1900.0', 'negated': False}],
#       'dst_city': [{'val': 'Neverland', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '5', 'negated': False}]},
#      'frame_id': 2,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'user',
#   'timestamp': 1471272508882.0},
#  {'db': {'result': [[], [], [], [], [], []],
#    'search': [{'ORIGIN_CITY': 'Caprica',
#      'PRICE_MIN': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272454.542,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MIN': '1700',
#      'NUM_ADULTS': '8',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272466.008,
#      'DESTINATION_CITY': 'Atlantis',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MAX': '1900',
#      'NUM_ADULTS': '5',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272562.484,
#      'DESTINATION_CITY': 'Neverland',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'PRICE_MAX': '1900',
#      'NUM_ADULTS': '5',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272571.739,
#      'DESTINATION_CITY': 'Neverland',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': '1472011200000'},
#     {'ORIGIN_CITY': 'Caprica',
#      'NUM_ADULTS': '5',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272625.733,
#      'DESTINATION_CITY': 'Neverland',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': 'NaN'},
#     {'ORIGIN_CITY': 'Caprica',
#      'NUM_ADULTS': '5',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272628.27,
#      'DESTINATION_CITY': 'Neverland',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': 'NaN'}]},
#   'text': 'I checked the availability for this date and there were no trips available.  Would you like to select some alternate dates?',
#   'labels': {'acts': [{'args': [{'val': [{'annotations': [{'val': None,
#            'key': 'str_date'}],
#          'frame': 2,
#          'fromrange': False}],
#        'key': 'ref'}],
#      'name': 'no_result'},
#     {'args': [{'key': 'str_date'}, {'key': 'end_date'}], 'name': 'suggest'}],
#    'active_frame': 2,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1900.0', 'negated': False}],
#       'dst_city': [{'val': 'Neverland', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '5', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 2,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'wizard',
#   'timestamp': 1471272800073.0},
#  {'text': 'I have no flexibility for dates... but I can leave from Atlantis rather than Caprica. How about that?',
#   'labels': {'acts': [{'args': [{'val': False, 'key': 'flex'}],
#      'name': 'inform'},
#     {'args': [{'val': 'Atlantis', 'key': 'or_city'}], 'name': 'inform'},
#     {'args': [{'val': [{'annotations': [{'val': 'Caprica', 'key': 'or_city'}],
#          'frame': 1,
#          'fromrange': False}],
#        'key': 'ref'}],
#      'name': 'negate'}],
#    'acts_without_refs': [{'args': [{'val': False, 'key': 'flex'}],
#      'name': 'inform'},
#     {'args': [{'val': 'Atlantis', 'key': 'or_city'}], 'name': 'inform'},
#     {'args': [{'val': 'Caprica', 'key': 'or_city'}], 'name': 'negate'}],
#    'active_frame': 3,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': True}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1900.0', 'negated': False}],
#       'dst_city': [{'val': 'Neverland', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '5', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 2,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'flex': [{'val': False, 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Atlantis', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}]},
#      'frame_id': 3,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'user',
#   'timestamp': 1471272833774.0},
#  {'db': {'result': [[]],
#    'search': [{'ORIGIN_CITY': 'Atlantis',
#      'PRICE_MAX': '1900',
#      'NUM_ADULTS': '5',
#      'RESULT_LIMIT': '10',
#      'timestamp': 1471272866.853,
#      'DESTINATION_CITY': 'Neverland',
#      'NUM_CHILDREN': '',
#      'ARE_DATES_FLEXIBLE': 'true',
#      'START_TIME': '1471060800000',
#      'END_TIME': 'NaN'}]},
#   'text': 'I checked the availability for that date and there were no trips available.  Would you like to select some alternate dates?',
#   'labels': {'acts': [{'args': [{'val': [{'annotations': [{'val': None,
#            'key': 'str_date'}],
#          'frame': 3,
#          'fromrange': False}],
#        'key': 'ref'}],
#      'name': 'no_result'},
#     {'args': [{'key': 'str_date'}, {'key': 'end_date'}], 'name': 'suggest'}],
#    'active_frame': 3,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': True}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1900.0', 'negated': False}],
#       'dst_city': [{'val': 'Neverland', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '5', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 2,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'flex': [{'val': False, 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Atlantis', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 3,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'wizard',
#   'timestamp': 1471273283370},
#  {'text': "I suppose I'll speak with my husband to see if we can choose other dates, and then I'll come back to you.Thanks for your help",
#   'labels': {'acts': [{'args': [], 'name': 'thankyou'}],
#    'acts_without_refs': [{'args': [], 'name': 'thankyou'}],
#    'active_frame': 3,
#    'frames': [{'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': True}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}]},
#      'frame_id': 1,
#      'requests': [],
#      'frame_parent_id': None,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1900.0', 'negated': False}],
#       'dst_city': [{'val': 'Neverland', 'negated': False}],
#       'or_city': [{'val': 'Caprica', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '5', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 2,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []},
#     {'info': {'intent': [{'val': 'book', 'negated': False}],
#       'budget': [{'val': '1700.0', 'negated': False}],
#       'flex': [{'val': False, 'negated': False}],
#       'dst_city': [{'val': 'Atlantis', 'negated': False}],
#       'or_city': [{'val': 'Atlantis', 'negated': False}],
#       'str_date': [{'val': 'august 13', 'negated': False}],
#       'n_adults': [{'val': '8', 'negated': False}],
#       'NO_RESULT': [{'val': True, 'negated': False}]},
#      'frame_id': 3,
#      'requests': [],
#      'frame_parent_id': 1,
#      'binary_questions': [],
#      'compare_requests': []}]},
#   'author': 'user',
#   'timestamp': 1471273458251}]

# %%
print(f"La première conversation contient {len(df[0]['turns'])} échanges.")

[(u['author'],u['text']) for u in df[0]['turns']]
# Out:
# La première conversation contient 7 échanges.
# [('user',
#   "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700."),
#  ('wizard',
#   'Hi...I checked a few options for you, and unfortunately, we do not currently have any trips that meet this criteria.  Would you like to book an alternate travel option?'),
#  ('user',
#   'Yes, how about going to Neverland from Caprica on August 13, 2016 for 5 adults. For this trip, my budget would be 1900.'),
#  ('wizard',
#   'I checked the availability for this date and there were no trips available.  Would you like to select some alternate dates?'),
#  ('user',
#   'I have no flexibility for dates... but I can leave from Atlantis rather than Caprica. How about that?'),
#  ('wizard',
#   'I checked the availability for that date and there were no trips available.  Would you like to select some alternate dates?'),
#  ('user',
#   "I suppose I'll speak with my husband to see if we can choose other dates, and then I'll come back to you.Thanks for your help")]

# %% [markdown]
# # Data préparation
#
# Nous préparons nos données afin que notre algoritme reconnaisse les entités suivante :
# - Ville de départ --> or_city
# - Ville de destination --> dst_city
# - Date aller souhaitée du vol --> str_date
# - Date retour souhaitée du vol --> end_date
# - Budget maximum pour le prix total des billets --> budget

# %%
mlEntityDefinition = ['or_city', 'dst_city','str_date','end_date','budget']

# %%
def collect_data(df,n):
    # Création d'une liste des textes accompagnés de leurs entités 
    base_data =[]
    
    # Sélection de n conversation du jeu de données
    for i in range(n):
        # Filtrage des réponses du bot
        data = [u for u in df[i]['turns'] if 'db' not in u.keys()]
        
        # Récupération des messages utilisateur avec leurs entités
        for messages in data: 
            text = messages['text']
            info = messages['labels']['frames'][-1]['info']
            [base_data.append((text, u,info[u][0]['val'])) for u in info.keys() if u in mlEntityDefinition]
     
    # Création d'un dataframe contenant le text l'entité et la valeur de l'entité
    base_data = pd.DataFrame(base_data, columns=['text', 'entit', 'val'])
    base_data.val = base_data.val.apply(lambda x: x.split('.')[0])
    
    # Filtre permettant de ne conserver uniquement les entité présent dans le text
    filtre = [base_data.val.values[n] in base_data.text.values[n] for n in range(len(base_data))]
    
    return base_data[filtre]

# Exemble de jeu de données pour les 8 premières conversions
messages = collect_data(df, len(df))
messages
# Out:
#                                                     text     entit        val
# 0      I'd like to book a trip to Atlantis from Capri...    budget       1700
# 1      I'd like to book a trip to Atlantis from Capri...  dst_city   Atlantis
# 2      I'd like to book a trip to Atlantis from Capri...   or_city    Caprica
# 4      Yes, how about going to Neverland from Caprica...    budget       1900
# 5      Yes, how about going to Neverland from Caprica...  dst_city  Neverland
# ...                                                  ...       ...        ...
# 37153  Fine, if you're going to be like that... I gue...   or_city  Frankfurt
# 37156  Is 3.5 stars the best you can do? Are you seri...  dst_city         St
# 37167  I need to book a trip for the whole family fro...   or_city      Tampa
# 37169  5 adults and 7 kids! Yup, the lot of us. We wa...    budget      32800
# 37176               Oh yes! Between September 12 and 26!  end_date         26
#
# [5839 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

v = messages.entit.value_counts().values
i = messages.entit.value_counts().index

plt.figure(figsize=(15,5))
sns.barplot(x=i,y=v)
plt.show()


plt.figure(figsize=(15,5))
sns.boxplot(messages.text.apply(lambda x: len(x)).values)
plt.show()

# %%
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Out:
#                                                     text     entit  \
# 145                           I need to back by the 31st  end_date
# 472    Ya for sure, not sure where, lets see what wou...  end_date
# 855              maybe the 15th of August until the 20th  end_date
# 1321                    august 18th. until september 2nd  end_date
# 1625       can we book the one that returns on the 18th?  end_date
# ...                                                  ...       ...
# 36682                                        S 20 to O 6  end_date
# 36707  Anytime between September 14 and 27 would be g...  end_date
# 36904  Hi there, I'm looking to go to Brasilia betwee...  end_date
# 37113      Sept 12 and we all need to be back by the 1st  end_date
# 37176               Oh yes! Between September 12 and 26!  end_date
#
#                val
# 145             31
# 472             16
# 855             20
# 1321   september 2
# 1625            18
# ...            ...
# 36682            6
# 36707           27
# 36904            4
# 37113            1
# 37176           26
#
# [324 rows x 3 columns]

# %%
# Fonction permettant de localiser les entités dans le text
def get_example_label(utterance, entity_name, value):
    """Build a EntityLabelObject.
    This will find the "value" start/end index in "utterance", and assign it to "entity name"
    """
    utterance = utterance.lower()
    value = value.lower()
    return {
        'entity_name': entity_name,
        'start_char_index': utterance.find(value),
        'end_char_index': utterance.find(value) + len(value)
    }

# Exemple de sortie
[get_example_label(test.text.iloc[n], test.entit.iloc[n], test.val.iloc[n]) for n in range(len(test))]
# Out:
# [{'entity_name': 'budget', 'start_char_index': 117, 'end_char_index': 121},
#  {'entity_name': 'dst_city', 'start_char_index': 27, 'end_char_index': 35},
#  {'entity_name': 'or_city', 'start_char_index': 41, 'end_char_index': 48},
#  {'entity_name': 'budget', 'start_char_index': 114, 'end_char_index': 118},
#  {'entity_name': 'dst_city', 'start_char_index': 24, 'end_char_index': 33},
#  {'entity_name': 'or_city', 'start_char_index': 39, 'end_char_index': 46},
#  {'entity_name': 'dst_city', 'start_char_index': 56, 'end_char_index': 64},
#  {'entity_name': 'or_city', 'start_char_index': 56, 'end_char_index': 64},
#  {'entity_name': 'or_city', 'start_char_index': 44, 'end_char_index': 55},
#  {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 69},
#  {'entity_name': 'budget', 'start_char_index': 75, 'end_char_index': 79},
#  {'entity_name': 'or_city', 'start_char_index': 23, 'end_char_index': 34},
#  {'entity_name': 'dst_city', 'start_char_index': 38, 'end_char_index': 47},
#  {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 32},
#  {'entity_name': 'budget', 'start_char_index': 74, 'end_char_index': 78},
#  {'entity_name': 'dst_city', 'start_char_index': 41, 'end_char_index': 50},
#  {'entity_name': 'or_city', 'start_char_index': 27, 'end_char_index': 38},
#  {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 46},
#  {'entity_name': 'budget', 'start_char_index': 74, 'end_char_index': 78},
#  {'entity_name': 'or_city', 'start_char_index': 60, 'end_char_index': 70},
#  {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 63, 'end_char_index': 74},
#  {'entity_name': 'budget', 'start_char_index': 24, 'end_char_index': 28},
#  {'entity_name': 'or_city', 'start_char_index': 12, 'end_char_index': 21},
#  {'entity_name': 'or_city', 'start_char_index': 19, 'end_char_index': 26},
#  {'entity_name': 'or_city', 'start_char_index': 37, 'end_char_index': 44},
#  {'entity_name': 'or_city', 'start_char_index': 34, 'end_char_index': 39},
#  {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 28},
#  {'entity_name': 'dst_city', 'start_char_index': 25, 'end_char_index': 36},
#  {'entity_name': 'budget', 'start_char_index': 68, 'end_char_index': 70},
#  {'entity_name': 'dst_city', 'start_char_index': 116, 'end_char_index': 122},
#  {'entity_name': 'or_city', 'start_char_index': 106, 'end_char_index': 111},
#  {'entity_name': 'dst_city', 'start_char_index': 71, 'end_char_index': 77},
#  {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 23},
#  {'entity_name': 'end_date', 'start_char_index': 22, 'end_char_index': 24},
#  {'entity_name': 'or_city', 'start_char_index': 9, 'end_char_index': 16},
#  {'entity_name': 'budget', 'start_char_index': 125, 'end_char_index': 129},
#  {'entity_name': 'dst_city', 'start_char_index': 26, 'end_char_index': 37},
#  {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 67},
#  {'entity_name': 'or_city', 'start_char_index': 41, 'end_char_index': 48},
#  {'entity_name': 'budget', 'start_char_index': 117, 'end_char_index': 121},
#  {'entity_name': 'dst_city', 'start_char_index': 48, 'end_char_index': 53},
#  {'entity_name': 'or_city', 'start_char_index': 83, 'end_char_index': 99},
#  {'entity_name': 'or_city', 'start_char_index': 55, 'end_char_index': 64},
#  {'entity_name': 'dst_city', 'start_char_index': 101, 'end_char_index': 109},
#  {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 30},
#  {'entity_name': 'dst_city', 'start_char_index': 50, 'end_char_index': 61},
#  {'entity_name': 'or_city', 'start_char_index': 27, 'end_char_index': 47},
#  {'entity_name': 'dst_city', 'start_char_index': 31, 'end_char_index': 40},
#  {'entity_name': 'dst_city', 'start_char_index': 39, 'end_char_index': 49},
#  {'entity_name': 'or_city', 'start_char_index': 24, 'end_char_index': 31},
#  {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 51},
#  {'entity_name': 'budget', 'start_char_index': 8, 'end_char_index': 13},
#  {'entity_name': 'dst_city', 'start_char_index': 20, 'end_char_index': 30},
#  {'entity_name': 'budget', 'start_char_index': 142, 'end_char_index': 146},
#  {'entity_name': 'or_city', 'start_char_index': 123, 'end_char_index': 130},
#  {'entity_name': 'budget', 'start_char_index': 95, 'end_char_index': 99},
#  {'entity_name': 'or_city', 'start_char_index': 37, 'end_char_index': 55},
#  {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 65},
#  {'entity_name': 'dst_city', 'start_char_index': 75, 'end_char_index': 89},
#  {'entity_name': 'or_city', 'start_char_index': 34, 'end_char_index': 61},
#  {'entity_name': 'dst_city', 'start_char_index': 87, 'end_char_index': 93},
#  {'entity_name': 'dst_city', 'start_char_index': 36, 'end_char_index': 43},
#  {'entity_name': 'dst_city', 'start_char_index': 55, 'end_char_index': 61},
#  {'entity_name': 'or_city', 'start_char_index': 61, 'end_char_index': 69},
#  {'entity_name': 'dst_city', 'start_char_index': 0, 'end_char_index': 7},
#  {'entity_name': 'or_city', 'start_char_index': 91, 'end_char_index': 101},
#  {'entity_name': 'dst_city', 'start_char_index': 77, 'end_char_index': 85},
#  {'entity_name': 'budget', 'start_char_index': 107, 'end_char_index': 111},
#  {'entity_name': 'dst_city', 'start_char_index': 30, 'end_char_index': 38},
#  {'entity_name': 'or_city', 'start_char_index': 21, 'end_char_index': 33},
#  {'entity_name': 'dst_city', 'start_char_index': 47, 'end_char_index': 56},
#  {'entity_name': 'budget', 'start_char_index': 73, 'end_char_index': 77},
#  {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 20},
#  {'entity_name': 'dst_city', 'start_char_index': 4, 'end_char_index': 13},
#  {'entity_name': 'or_city', 'start_char_index': 18, 'end_char_index': 25},
#  {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 35},
#  {'entity_name': 'str_date', 'start_char_index': 46, 'end_char_index': 48},
#  {'entity_name': 'dst_city', 'start_char_index': 44, 'end_char_index': 60},
#  {'entity_name': 'budget', 'start_char_index': 68, 'end_char_index': 72},
#  {'entity_name': 'or_city', 'start_char_index': 50, 'end_char_index': 65},
#  {'entity_name': 'budget', 'start_char_index': 40, 'end_char_index': 44},
#  {'entity_name': 'dst_city', 'start_char_index': 57, 'end_char_index': 73},
#  {'entity_name': 'or_city', 'start_char_index': 26, 'end_char_index': 33},
#  {'entity_name': 'budget', 'start_char_index': 83, 'end_char_index': 87},
#  {'entity_name': 'dst_city', 'start_char_index': 39, 'end_char_index': 55},
#  {'entity_name': 'or_city', 'start_char_index': 112, 'end_char_index': 119},
#  {'entity_name': 'dst_city', 'start_char_index': 93, 'end_char_index': 104},
#  {'entity_name': 'or_city', 'start_char_index': 0, 'end_char_index': 8},
#  {'entity_name': 'dst_city', 'start_char_index': 83, 'end_char_index': 90},
#  {'entity_name': 'dst_city', 'start_char_index': 104, 'end_char_index': 109},
#  {'entity_name': 'dst_city', 'start_char_index': 0, 'end_char_index': 5},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 18},
#  {'entity_name': 'dst_city', 'start_char_index': 49, 'end_char_index': 55},
#  {'entity_name': 'end_date', 'start_char_index': 97, 'end_char_index': 99},
#  {'entity_name': 'or_city', 'start_char_index': 25, 'end_char_index': 35},
#  {'entity_name': 'or_city', 'start_char_index': 25, 'end_char_index': 40},
#  {'entity_name': 'dst_city', 'start_char_index': 70, 'end_char_index': 77},
#  {'entity_name': 'budget', 'start_char_index': 99, 'end_char_index': 103},
#  {'entity_name': 'or_city', 'start_char_index': 15, 'end_char_index': 23},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 21},
#  {'entity_name': 'str_date', 'start_char_index': 61, 'end_char_index': 63},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 18},
#  {'entity_name': 'or_city', 'start_char_index': 26, 'end_char_index': 35},
#  {'entity_name': 'or_city', 'start_char_index': 28, 'end_char_index': 36},
#  {'entity_name': 'or_city', 'start_char_index': 58, 'end_char_index': 69},
#  {'entity_name': 'budget', 'start_char_index': 20, 'end_char_index': 24},
#  {'entity_name': 'dst_city', 'start_char_index': 109, 'end_char_index': 118},
#  {'entity_name': 'or_city', 'start_char_index': 173, 'end_char_index': 178},
#  {'entity_name': 'dst_city', 'start_char_index': 50, 'end_char_index': 59},
#  {'entity_name': 'or_city', 'start_char_index': 73, 'end_char_index': 89},
#  {'entity_name': 'dst_city', 'start_char_index': 36, 'end_char_index': 45},
#  {'entity_name': 'or_city', 'start_char_index': 14, 'end_char_index': 19},
#  {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 51},
#  {'entity_name': 'dst_city', 'start_char_index': 25, 'end_char_index': 35},
#  {'entity_name': 'dst_city', 'start_char_index': 34, 'end_char_index': 44},
#  {'entity_name': 'or_city', 'start_char_index': 28, 'end_char_index': 33},
#  {'entity_name': 'dst_city', 'start_char_index': 88, 'end_char_index': 94},
#  {'entity_name': 'budget', 'start_char_index': 114, 'end_char_index': 118},
#  {'entity_name': 'dst_city', 'start_char_index': 74, 'end_char_index': 82},
#  {'entity_name': 'or_city', 'start_char_index': 88, 'end_char_index': 98},
#  {'entity_name': 'dst_city', 'start_char_index': 40, 'end_char_index': 50},
#  {'entity_name': 'or_city', 'start_char_index': 40, 'end_char_index': 50},
#  {'entity_name': 'dst_city', 'start_char_index': 86, 'end_char_index': 92},
#  {'entity_name': 'or_city', 'start_char_index': 39, 'end_char_index': 44},
#  {'entity_name': 'or_city', 'start_char_index': 112, 'end_char_index': 120},
#  {'entity_name': 'budget', 'start_char_index': 22, 'end_char_index': 26},
#  {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 52},
#  {'entity_name': 'or_city', 'start_char_index': 24, 'end_char_index': 33},
#  {'entity_name': 'budget', 'start_char_index': 29, 'end_char_index': 33},
#  {'entity_name': 'or_city', 'start_char_index': 23, 'end_char_index': 34},
#  {'entity_name': 'dst_city', 'start_char_index': 87, 'end_char_index': 95},
#  {'entity_name': 'or_city', 'start_char_index': 93, 'end_char_index': 98},
#  {'entity_name': 'str_date', 'start_char_index': 14, 'end_char_index': 15},
#  {'entity_name': 'or_city', 'start_char_index': 32, 'end_char_index': 43},
#  {'entity_name': 'or_city', 'start_char_index': 10, 'end_char_index': 25},
#  {'entity_name': 'str_date', 'start_char_index': 37, 'end_char_index': 38},
#  {'entity_name': 'or_city', 'start_char_index': 17, 'end_char_index': 23},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 21},
#  {'entity_name': 'dst_city', 'start_char_index': 15, 'end_char_index': 22},
#  {'entity_name': 'end_date', 'start_char_index': 35, 'end_char_index': 37},
#  {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 33},
#  {'entity_name': 'dst_city', 'start_char_index': 95, 'end_char_index': 104},
#  {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 29},
#  {'entity_name': 'or_city', 'start_char_index': 60, 'end_char_index': 66},
#  {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 54},
#  {'entity_name': 'dst_city', 'start_char_index': 17, 'end_char_index': 29},
#  {'entity_name': 'or_city', 'start_char_index': 22, 'end_char_index': 28},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 23},
#  {'entity_name': 'or_city', 'start_char_index': 66, 'end_char_index': 74},
#  {'entity_name': 'dst_city', 'start_char_index': 52, 'end_char_index': 60},
#  {'entity_name': 'budget', 'start_char_index': 51, 'end_char_index': 55},
#  {'entity_name': 'dst_city', 'start_char_index': 54, 'end_char_index': 62},
#  {'entity_name': 'budget', 'start_char_index': 139, 'end_char_index': 143},
#  {'entity_name': 'dst_city', 'start_char_index': 35, 'end_char_index': 43},
#  {'entity_name': 'or_city', 'start_char_index': 99, 'end_char_index': 111},
#  {'entity_name': 'budget', 'start_char_index': 28, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 33},
#  {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 23},
#  {'entity_name': 'or_city', 'start_char_index': 25, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 53, 'end_char_index': 61},
#  {'entity_name': 'dst_city', 'start_char_index': 60, 'end_char_index': 71},
#  {'entity_name': 'or_city', 'start_char_index': 80, 'end_char_index': 92},
#  {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 20},
#  {'entity_name': 'dst_city', 'start_char_index': 23, 'end_char_index': 41},
#  {'entity_name': 'or_city', 'start_char_index': 5, 'end_char_index': 14},
#  {'entity_name': 'or_city', 'start_char_index': 136, 'end_char_index': 141},
#  {'entity_name': 'dst_city', 'start_char_index': 97, 'end_char_index': 108},
#  {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 24},
#  {'entity_name': 'dst_city', 'start_char_index': 93, 'end_char_index': 100},
#  {'entity_name': 'dst_city', 'start_char_index': 43, 'end_char_index': 49},
#  {'entity_name': 'budget', 'start_char_index': 29, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 31, 'end_char_index': 40},
#  {'entity_name': 'or_city', 'start_char_index': 28, 'end_char_index': 37},
#  {'entity_name': 'dst_city', 'start_char_index': 34, 'end_char_index': 41},
#  {'entity_name': 'or_city', 'start_char_index': 34, 'end_char_index': 44},
#  {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28},
#  {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 40},
#  {'entity_name': 'or_city', 'start_char_index': 43, 'end_char_index': 53},
#  {'entity_name': 'or_city', 'start_char_index': 43, 'end_char_index': 48},
#  {'entity_name': 'dst_city', 'start_char_index': 67, 'end_char_index': 73},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 15},
#  {'entity_name': 'dst_city', 'start_char_index': 6, 'end_char_index': 11},
#  {'entity_name': 'str_date', 'start_char_index': 0, 'end_char_index': 9},
#  {'entity_name': 'end_date', 'start_char_index': 19, 'end_char_index': 30},
#  {'entity_name': 'dst_city', 'start_char_index': 71, 'end_char_index': 78},
#  {'entity_name': 'or_city', 'start_char_index': 30, 'end_char_index': 35},
#  {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 24},
#  {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 63},
#  {'entity_name': 'dst_city', 'start_char_index': 4, 'end_char_index': 8},
#  {'entity_name': 'or_city', 'start_char_index': 53, 'end_char_index': 65},
#  {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 33},
#  {'entity_name': 'str_date', 'start_char_index': 83, 'end_char_index': 85},
#  {'entity_name': 'dst_city', 'start_char_index': 41, 'end_char_index': 46},
#  {'entity_name': 'or_city', 'start_char_index': 31, 'end_char_index': 36},
#  {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 25},
#  {'entity_name': 'or_city', 'start_char_index': 54, 'end_char_index': 68},
#  {'entity_name': 'or_city', 'start_char_index': 55, 'end_char_index': 60},
#  {'entity_name': 'dst_city', 'start_char_index': 36, 'end_char_index': 41},
#  {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 20},
#  {'entity_name': 'dst_city', 'start_char_index': 10, 'end_char_index': 19},
#  {'entity_name': 'or_city', 'start_char_index': 31, 'end_char_index': 45},
#  {'entity_name': 'dst_city', 'start_char_index': 25, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 30, 'end_char_index': 35},
#  {'entity_name': 'or_city', 'start_char_index': 5, 'end_char_index': 14},
#  {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 21},
#  {'entity_name': 'or_city', 'start_char_index': 33, 'end_char_index': 44},
#  {'entity_name': 'dst_city', 'start_char_index': 17, 'end_char_index': 24},
#  {'entity_name': 'or_city', 'start_char_index': 9, 'end_char_index': 19},
#  {'entity_name': 'or_city', 'start_char_index': 92, 'end_char_index': 99},
#  {'entity_name': 'dst_city', 'start_char_index': 27, 'end_char_index': 31},
#  {'entity_name': 'dst_city', 'start_char_index': 3, 'end_char_index': 8},
#  {'entity_name': 'dst_city', 'start_char_index': 23, 'end_char_index': 28},
#  {'entity_name': 'or_city', 'start_char_index': 10, 'end_char_index': 16},
#  {'entity_name': 'dst_city', 'start_char_index': 25, 'end_char_index': 34},
#  {'entity_name': 'or_city', 'start_char_index': 27, 'end_char_index': 33},
#  {'entity_name': 'dst_city', 'start_char_index': 64, 'end_char_index': 70},
#  {'entity_name': 'dst_city', 'start_char_index': 64, 'end_char_index': 74},
#  {'entity_name': 'str_date', 'start_char_index': 19, 'end_char_index': 21},
#  {'entity_name': 'end_date', 'start_char_index': 40, 'end_char_index': 42},
#  {'entity_name': 'dst_city', 'start_char_index': 25, 'end_char_index': 33},
#  {'entity_name': 'or_city', 'start_char_index': 31, 'end_char_index': 35},
#  {'entity_name': 'end_date', 'start_char_index': 70, 'end_char_index': 82},
#  {'entity_name': 'dst_city', 'start_char_index': 60, 'end_char_index': 70},
#  {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 26},
#  {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 56},
#  {'entity_name': 'dst_city', 'start_char_index': 75, 'end_char_index': 87},
#  {'entity_name': 'or_city', 'start_char_index': 97, 'end_char_index': 102},
#  {'entity_name': 'dst_city', 'start_char_index': 33, 'end_char_index': 43},
#  {'entity_name': 'or_city', 'start_char_index': 69, 'end_char_index': 79},
#  {'entity_name': 'dst_city', 'start_char_index': 89, 'end_char_index': 94},
#  {'entity_name': 'or_city', 'start_char_index': 72, 'end_char_index': 77},
#  {'entity_name': 'dst_city', 'start_char_index': 72, 'end_char_index': 77},
#  {'entity_name': 'or_city', 'start_char_index': 10, 'end_char_index': 18},
#  {'entity_name': 'dst_city', 'start_char_index': 101, 'end_char_index': 110},
#  {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28},
#  {'entity_name': 'dst_city', 'start_char_index': 31, 'end_char_index': 36},
#  {'entity_name': 'dst_city', 'start_char_index': 30, 'end_char_index': 36},
#  {'entity_name': 'dst_city', 'start_char_index': 4, 'end_char_index': 10},
#  {'entity_name': 'or_city', 'start_char_index': 25, 'end_char_index': 33},
#  {'entity_name': 'budget', 'start_char_index': 131, 'end_char_index': 135},
#  {'entity_name': 'or_city', 'start_char_index': 22, 'end_char_index': 37},
#  {'entity_name': 'or_city', 'start_char_index': 45, 'end_char_index': 49},
#  {'entity_name': 'budget', 'start_char_index': 35, 'end_char_index': 39},
#  {'entity_name': 'or_city', 'start_char_index': 14, 'end_char_index': 19},
#  {'entity_name': 'dst_city', 'start_char_index': 41, 'end_char_index': 46},
#  {'entity_name': 'budget', 'start_char_index': 1, 'end_char_index': 6},
#  {'entity_name': 'dst_city', 'start_char_index': 23, 'end_char_index': 30},
#  {'entity_name': 'or_city', 'start_char_index': 37, 'end_char_index': 41},
#  {'entity_name': 'dst_city', 'start_char_index': 8, 'end_char_index': 15},
#  {'entity_name': 'dst_city', 'start_char_index': 35, 'end_char_index': 44},
#  {'entity_name': 'or_city', 'start_char_index': 5, 'end_char_index': 9},
#  {'entity_name': 'dst_city', 'start_char_index': 24, 'end_char_index': 32},
#  {'entity_name': 'dst_city', 'start_char_index': 15, 'end_char_index': 22},
#  {'entity_name': 'str_date', 'start_char_index': 24, 'end_char_index': 26},
#  {'entity_name': 'dst_city', 'start_char_index': 51, 'end_char_index': 59},
#  {'entity_name': 'or_city', 'start_char_index': 19, 'end_char_index': 34},
#  {'entity_name': 'or_city', 'start_char_index': 20, 'end_char_index': 30},
#  {'entity_name': 'budget', 'start_char_index': 1, 'end_char_index': 2},
#  {'entity_name': 'or_city', 'start_char_index': 110, 'end_char_index': 118},
#  {'entity_name': 'budget', 'start_char_index': 63, 'end_char_index': 68},
#  {'entity_name': 'dst_city', 'start_char_index': 20, 'end_char_index': 29},
#  {'entity_name': 'or_city', 'start_char_index': 24, 'end_char_index': 30},
#  {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 40},
#  {'entity_name': 'or_city', 'start_char_index': 22, 'end_char_index': 29},
#  {'entity_name': 'dst_city', 'start_char_index': 31, 'end_char_index': 38},
#  {'entity_name': 'or_city', 'start_char_index': 10, 'end_char_index': 18},
#  {'entity_name': 'or_city', 'start_char_index': 18, 'end_char_index': 28},
#  {'entity_name': 'dst_city', 'start_char_index': 62, 'end_char_index': 67},
#  {'entity_name': 'end_date', 'start_char_index': 42, 'end_char_index': 44},
#  {'entity_name': 'dst_city', 'start_char_index': 161, 'end_char_index': 166},
#  {'entity_name': 'or_city', 'start_char_index': 129, 'end_char_index': 137},
#  {'entity_name': 'dst_city', 'start_char_index': 135, 'end_char_index': 140},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 20},
#  {'entity_name': 'dst_city', 'start_char_index': 38, 'end_char_index': 46},
#  {'entity_name': 'or_city', 'start_char_index': 17, 'end_char_index': 33},
#  {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 21},
#  {'entity_name': 'or_city', 'start_char_index': 38, 'end_char_index': 45},
#  {'entity_name': 'or_city', 'start_char_index': 10, 'end_char_index': 17},
#  {'entity_name': 'dst_city', 'start_char_index': 60, 'end_char_index': 65},
#  {'entity_name': 'dst_city', 'start_char_index': 20, 'end_char_index': 30},
#  {'entity_name': 'dst_city', 'start_char_index': 10, 'end_char_index': 14},
#  {'entity_name': 'or_city', 'start_char_index': 34, 'end_char_index': 41},
#  {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28},
#  {'entity_name': 'or_city', 'start_char_index': 19, 'end_char_index': 26},
#  {'entity_name': 'or_city', 'start_char_index': 16, 'end_char_index': 26},
#  {'entity_name': 'dst_city', 'start_char_index': 47, 'end_char_index': 57},
#  {'entity_name': 'or_city', 'start_char_index': 0, 'end_char_index': 9},
#  {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 67},
#  {'entity_name': 'or_city', 'start_char_index': 0, 'end_char_index': 7},
#  {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 25},
#  {'entity_name': 'or_city', 'start_char_index': 87, 'end_char_index': 93},
#  {'entity_name': 'dst_city', 'start_char_index': 56, 'end_char_index': 62},
#  {'entity_name': 'dst_city', 'start_char_index': 34, 'end_char_index': 38},
#  {'entity_name': 'budget', 'start_char_index': 28, 'end_char_index': 32}]

# %%
# Fonction permettant de sortir le jeu de données sous format json en vu d'interpretation par le model Luois
def labeledExampleUtterance(data, intentName = "FlyMe.Booking"):
    
    data_Uterance = []
    for text in data.text.unique():
        data_temp = data[data.text == text][['entit','val']]
        data_json = {
            "text": text,
            "intentName": intentName,
            "entityLabels": [get_example_label(text, data_temp.entit.iloc[n], data_temp.val.iloc[n]) 
                             for n in range(len(data_temp))]
        }
        data_Uterance.append(data_json)
        
    return data_Uterance


# Exemple de sortie de fonction

labeledExampleUtteranceWithMLEntity = labeledExampleUtterance(test)
labeledExampleUtteranceWithMLEntity
# Out:
# [{'text': "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 117,
#     'end_char_index': 121},
#    {'entity_name': 'dst_city', 'start_char_index': 27, 'end_char_index': 35},
#    {'entity_name': 'or_city', 'start_char_index': 41, 'end_char_index': 48}]},
#  {'text': 'Yes, how about going to Neverland from Caprica on August 13, 2016 for 5 adults. For this trip, my budget would be 1900.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 114,
#     'end_char_index': 118},
#    {'entity_name': 'dst_city', 'start_char_index': 24, 'end_char_index': 33},
#    {'entity_name': 'or_city', 'start_char_index': 39, 'end_char_index': 46}]},
#  {'text': 'I have no flexibility for dates... but I can leave from Atlantis rather than Caprica. How about that?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 56,
#     'end_char_index': 64},
#    {'entity_name': 'or_city', 'start_char_index': 56, 'end_char_index': 64}]},
#  {'text': 'Hello, I am looking to book a vacation from Gotham City to Mos Eisley for $2100.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 44,
#     'end_char_index': 55},
#    {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 69},
#    {'entity_name': 'budget', 'start_char_index': 75, 'end_char_index': 79}]},
#  {'text': 'What about a trip from Gotham City to Neverland for the same budget?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 23,
#     'end_char_index': 34},
#    {'entity_name': 'dst_city', 'start_char_index': 38, 'end_char_index': 47}]},
#  {'text': 'Would any packages to Mos Eisley be available if I increase my budget to $2500?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 32},
#    {'entity_name': 'budget', 'start_char_index': 74, 'end_char_index': 78}]},
#  {'text': "You know what, I'd like to try and visit Neverland",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 41,
#     'end_char_index': 50}]},
#  {'text': 'Do you have any trips from Gotham City to Kobe for my original budget of $2100?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 27,
#     'end_char_index': 38},
#    {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 46},
#    {'entity_name': 'budget', 'start_char_index': 74, 'end_char_index': 78}]},
#  {'text': "No, that's too far for me. I need a flight that leaves from Birmingham.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 60,
#     'end_char_index': 70}]},
#  {'text': 'How many days would I be in Kobe?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 32}]},
#  {'text': 'Hello there i am looking to go on a vacation with my family to Gotham City, can you help me?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 63,
#     'end_char_index': 74}]},
#  {'text': 'yes i do, it is around $2200',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 24,
#     'end_char_index': 28}]},
#  {'text': 'We are from Neverland',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 12,
#     'end_char_index': 21}]},
#  {'text': 'we can depart from Toronto',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 19,
#     'end_char_index': 26}]},
#  {'text': 'hmm what options would i have out of Toronto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 37,
#     'end_char_index': 44}]},
#  {'text': "Hi I'd like to go to Caprica from Busan, between Sunday August 21, 2016 and Wednesday August 31, 2016",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 39},
#    {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 28}]},
#  {'text': 'Do you have anything for San Antonio as a destination?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 36}]},
#  {'text': 'Hello, I am looking to book a trip for 2 adults and 6 children for $21,300 or less. We are departing from Kochi for Denver.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 68,
#     'end_char_index': 70},
#    {'entity_name': 'dst_city', 'start_char_index': 116, 'end_char_index': 122},
#    {'entity_name': 'or_city',
#     'start_char_index': 106,
#     'end_char_index': 111}]},
#  {'text': 'I do not have any dates in mind. I would like to spend as much time in Denver as my budget will allow.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 71,
#     'end_char_index': 77}]},
#  {'text': 'Hey, i Want to go to St. Louis on the 17th of August',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 23}]},
#  {'text': 'I need to back by the 31st',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 22,
#     'end_char_index': 24}]},
#  {'text': 'I’m from Calgary',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 9,
#     'end_char_index': 16}]},
#  {'text': "I'm looking for a trip to Gotham City leaving from Kakariko Village on Saturday, August 13, 2016. 3 adults for no more than $2400 USD.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 125,
#     'end_char_index': 129},
#    {'entity_name': 'dst_city', 'start_char_index': 26, 'end_char_index': 37},
#    {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 67}]},
#  {'text': "I'd like to adjust the departure city to Caprica.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 41,
#     'end_char_index': 48}]},
#  {'text': 'The dates cannot be changed. How about going to Theed with 14 adults, leaving from Kakariko Village, on a budget of $2900?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 117,
#     'end_char_index': 121},
#    {'entity_name': 'dst_city', 'start_char_index': 48, 'end_char_index': 53},
#    {'entity_name': 'or_city', 'start_char_index': 83, 'end_char_index': 99}]},
#  {'text': 'Hello, I would like to book a 2-week trip leaving from Melbourne on August 27. I would like to go to Mannheim.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 55,
#     'end_char_index': 64},
#    {'entity_name': 'dst_city',
#     'start_char_index': 101,
#     'end_char_index': 109}]},
#  {'text': 'Is there a package to Mannheim which offers a cheaper hotel? I am flexible with my dates of arrival and departure.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 30}]},
#  {'text': 'What would the cost be if I stayed for 10 days in Mexico City?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 50,
#     'end_char_index': 61}]},
#  {'text': 'Actually I am leaving from Melbourne, Australia. How does this affect the price of the trip?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 27,
#     'end_char_index': 47}]},
#  {'text': 'Could I purchase a package  to Vancouver similar to the one I was offered?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 31,
#     'end_char_index': 40}]},
#  {'text': 'Hello, I am planning to book a trip to pittsborgh',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 39,
#     'end_char_index': 49}]},
#  {'text': 'We will be leaving from Fukuoka',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 24,
#     'end_char_index': 31}]},
#  {'text': 'I would like to see the availabilities in Vancouver please',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 42,
#     'end_char_index': 51}]},
#  {'text': 'I have $12600 to spend on this vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 8,
#     'end_char_index': 13}]},
#  {'text': 'Hi, I need to go to Mos Eisley for a wedding, leaving on Saturday, August 13, 2016 and returning on Tuesday, August 16, 2016. Preferably for $3700.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 20,
#     'end_char_index': 30},
#    {'entity_name': 'budget', 'start_char_index': 142, 'end_char_index': 146}]},
#  {'text': "I'd like to get away from Monday, August 15, 2016 to Wednesday, August 31, 2016. My budget is $3200 and I would leave from Detroit.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 123,
#     'end_char_index': 130},
#    {'entity_name': 'budget', 'start_char_index': 95, 'end_char_index': 99}]},
#  {'text': 'Good day, please book me a trip from Vancouver, Jamaica to Recife. I would like to leave for 17 days on August 24.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 37,
#     'end_char_index': 55},
#    {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 65}]},
#  {'text': 'I would not like to travel to Vancouver, Canada.  Do you have any trips to Recife, Brazil?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 75,
#     'end_char_index': 89}]},
#  {'text': 'Actually I will be departing from Vancouver, British Columbia, do you have packages to Recife?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 61},
#    {'entity_name': 'dst_city', 'start_char_index': 87, 'end_char_index': 93}]},
#  {'text': 'Do you have any similar packages to Goiania?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 36,
#     'end_char_index': 43}]},
#  {'text': 'Actually I would like to purchase the first package to Recife.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 55,
#     'end_char_index': 61}]},
#  {'text': 'Hi im looking for a nice destination that i could go to from Columbus',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 61,
#     'end_char_index': 69}]},
#  {'text': 'Toronto seems like a better place this time of year, when would the flights be?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 0,
#     'end_char_index': 7}]},
#  {'text': "Hi, I have a big family and we can't afford a big vacation, we want to go to Atlantis from Mos Eisley for $3600 at most.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 91,
#     'end_char_index': 101},
#    {'entity_name': 'dst_city', 'start_char_index': 77, 'end_char_index': 85},
#    {'entity_name': 'budget', 'start_char_index': 107, 'end_char_index': 111}]},
#  {'text': 'No, we are visiting family in Atlantis. Can you check once more please?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 30,
#     'end_char_index': 38}]},
#  {'text': "Hi, I'm leaving from Diagon Alley and going to Coruscant on a budget of $3400. The dates don't matter, but I cannot afford anything over my budget.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 21,
#     'end_char_index': 33},
#    {'entity_name': 'dst_city', 'start_char_index': 47, 'end_char_index': 56},
#    {'entity_name': 'budget', 'start_char_index': 73, 'end_char_index': 77}]},
#  {'text': 'What about Neverland on the same budget?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 20}]},
#  {'text': 'nor Coruscant?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 4,
#     'end_char_index': 13}]},
#  {'text': 'Hi there, im from Vitoria and I want to go on vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 18,
#     'end_char_index': 25}]},
#  {'text': 'I would like to go to Santo domingo',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 35}]},
#  {'text': 'yes that sounds fine, looking to leave on the 19th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 46,
#     'end_char_index': 48}]},
#  {'text': 'Hi, me and my family want to take a trip to Kakariko Village.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 44,
#     'end_char_index': 60}]},
#  {'text': "We are four adults and 11 children departing from Godric's Hollow. $3500 is the most we are willing to spend.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 68,
#     'end_char_index': 72},
#    {'entity_name': 'or_city', 'start_char_index': 50, 'end_char_index': 65}]},
#  {'text': 'I would not be able to spend more than $4500',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 40,
#     'end_char_index': 44}]},
#  {'text': "We'll catch a flight from Toronto then. We're headed for Kakariko Village.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 57,
#     'end_char_index': 73},
#    {'entity_name': 'or_city', 'start_char_index': 26, 'end_char_index': 33}]},
#  {'text': 'Ok, do you have any travel packages to Kingston, Canada for 11 kids and 4 adults, $3500 or less, departing from Toronto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 83,
#     'end_char_index': 87},
#    {'entity_name': 'dst_city', 'start_char_index': 39, 'end_char_index': 55},
#    {'entity_name': 'or_city',
#     'start_char_index': 112,
#     'end_char_index': 119}]},
#  {'text': "Hi, I'm looking for a trip  from Thursday, August 18, 2016 to Thursday, September 8, 2016 to Mexico City",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 93,
#     'end_char_index': 104}]},
#  {'text': 'Kingston',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 0,
#     'end_char_index': 8}]},
#  {'text': "I prefer 3 stars and above. I'm flexible with my budget, is there anything else in Columbo?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 83,
#     'end_char_index': 90}]},
#  {'text': "That's looking good. I want to see a few more options before I choose one. There's nothing available in Porto?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 104,
#     'end_char_index': 109}]},
#  {'text': 'Porto would be great. Can you tell me more about the hotel.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 0,
#     'end_char_index': 5}]},
#  {'text': 'Hi im from Caprica looking to book a vacation to Hyrule',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 18},
#    {'entity_name': 'dst_city', 'start_char_index': 49, 'end_char_index': 55}]},
#  {'text': 'Ya for sure, not sure where, lets see what would fit my plans between the 13th of august and the 16th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 97,
#     'end_char_index': 99}]},
#  {'text': 'How about if i leave fro Birmingham?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 35}]},
#  {'text': "Hey man, imma leave from Godric's Hollow on August 27, 2016 and go to Goiania. Can't pay more than 4300USD. Watcha got?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 40},
#    {'entity_name': 'dst_city', 'start_char_index': 70, 'end_char_index': 77},
#    {'entity_name': 'budget', 'start_char_index': 99, 'end_char_index': 103}]},
#  {'text': 'yeah how about Montreal?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 15,
#     'end_char_index': 23}]},
#  {'text': 'HI im from Alexandria looking to book a 12 day vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'Hi im from termina can we find a vacation that starts on the 13th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 61,
#     'end_char_index': 63},
#    {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 18}]},
#  {'text': 'How about if i leave from Vancouver where would i be able to go?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 26,
#     'end_char_index': 35}]},
#  {'text': 'and if i were to leave from columbus?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 28,
#     'end_char_index': 36}]},
#  {'text': 'i have a budget of $3000, and let’s say that i leave from Mexico City',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 58,
#     'end_char_index': 69},
#    {'entity_name': 'budget', 'start_char_index': 20, 'end_char_index': 24}]},
#  {'text': "Hi. I'm looking for an adventure from Thursday, August 18 to Saturday, September 3. I'm thinking of going to Fortaleza. Yes, with free breakfast of course. I'm leaving from Essen.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 109,
#     'end_char_index': 118},
#    {'entity_name': 'or_city',
#     'start_char_index': 173,
#     'end_char_index': 178}]},
#  {'text': "Hi, my name is Harry Potter and I'd like to go to Hogsmeade leaving from Kakariko Village on Saturday, August 13th for 3 nights with 11 friends.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 50,
#     'end_char_index': 59},
#    {'entity_name': 'or_city', 'start_char_index': 73, 'end_char_index': 89}]},
#  {'text': "What? No. I'm looking for a trip to Hogsmeade with 11 of my friends.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 36,
#     'end_char_index': 45}]},
#  {'text': "Hi. I live in Busan and I'd like to go to Las Vegas from Wednesday August 17 to Monday September 5. What's available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 14,
#     'end_char_index': 19},
#    {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 51}]},
#  {'text': 'How much is a package to Punta Cana?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 35}]},
#  {'text': "I'd like to compare the Cairo and Punta Cana packages. What are the hotels, how many stars, free wifi, free breakfast?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 34,
#     'end_char_index': 44}]},
#  {'text': 'Hello, I want to leave from Seoul on August 27 and return on September 9. You can go to Manaus.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 28,
#     'end_char_index': 33},
#    {'entity_name': 'dst_city', 'start_char_index': 88, 'end_char_index': 94}]},
#  {'text': "I'm a polygamist and I'd like to travel with my 6 partners and 1 child to San Juan from Pittsburgh on a budget of 6600 USD",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 114,
#     'end_char_index': 118},
#    {'entity_name': 'dst_city', 'start_char_index': 74, 'end_char_index': 82},
#    {'entity_name': 'or_city', 'start_char_index': 88, 'end_char_index': 98}]},
#  {'text': "Ok I'll book the package with 8 days in Pittsburgh from August 17th to the 24th. Thank you.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 40,
#     'end_char_index': 50},
#    {'entity_name': 'or_city', 'start_char_index': 40, 'end_char_index': 50}]},
#  {'text': "Hi, send me on a 10 day-trip away from Cairo. I'd like to leave August 15. Send me to Sendai. Money is not object",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 86,
#     'end_char_index': 92},
#    {'entity_name': 'or_city', 'start_char_index': 39, 'end_char_index': 44}]},
#  {'text': "Good afternoon, I'd like to book a trip with my son from August 18 to August 29. He and I would be leaving from Curitiba. What destinations can you offer?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 112,
#     'end_char_index': 120}]},
#  {'text': 'Is there anything for 2600USD between the dates of August 18 and August 29th? For less than 10 days?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 22,
#     'end_char_index': 26}]},
#  {'text': 'Hi, my family and i are booking a trip to Sacramento, can you help us?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 42,
#     'end_char_index': 52}]},
#  {'text': 'we would be coming from San Diego',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 24,
#     'end_char_index': 33}]},
#  {'text': 'im willing to spend at most $4200',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 29,
#     'end_char_index': 33}]},
#  {'text': "Hi I need a break from Gotham City, the crime rate is just too high. I'd like to go to Hogsmead with 3 kids and 9 adults.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 23,
#     'end_char_index': 34},
#    {'entity_name': 'dst_city', 'start_char_index': 87, 'end_char_index': 95}]},
#  {'text': 'Hello, I have 15 vacation days available between June 1st and August 31st. I am leaving from Theed. I would like to go somewhere with lots of sunshine.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 93,
#     'end_char_index': 98},
#    {'entity_name': 'str_date', 'start_char_index': 14, 'end_char_index': 15}]},
#  {'text': 'Do you have any departures from Kobe, Japan?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 32,
#     'end_char_index': 43}]},
#  {'text': 'How about Birmingham City?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 25}]},
#  {'text': 'I can extend my vacation time to the 14th of September, does this open up any new options?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 37,
#     'end_char_index': 38}]},
#  {'text': "Hello! I live in Munich and I'd like to book any kind of trip between Monday, August 15th and Friday August 26th for 3 adults and 3 kids.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 17,
#     'end_char_index': 23}]},
#  {'text': 'Hi im from punta cana looking to go on a trip',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'Im thinking to Fukuoka',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 15,
#     'end_char_index': 22}]},
#  {'text': 'maybe the 15th of August until the 20th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 35,
#     'end_char_index': 37}]},
#  {'text': 'and what if i were to go to Essen?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 33}]},
#  {'text': 'these dates don’t look like they would be compatible with my schedule. Hey, how about going to hiroshima?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 95,
#     'end_char_index': 104}]},
#  {'text': 'Is there a flight to Santiago',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 29}]},
#  {'text': 'Hey! You can help me by finding a trip to Philadelphia from Maceio.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 60,
#     'end_char_index': 66},
#    {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 54}]},
#  {'text': "Let's start with Philadelphia, how much is it I upgrade to business class?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 17,
#     'end_char_index': 29}]},
#  {'text': 'Good idea. What about Canoas?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 22,
#     'end_char_index': 28}]},
#  {'text': 'What about porto alegre',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 23}]},
#  {'text': "Good afternoon. I'd like to book a business trip to New York from Mannheim. What can you offer?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 66,
#     'end_char_index': 74},
#    {'entity_name': 'dst_city', 'start_char_index': 52, 'end_char_index': 60}]},
#  {'text': "Dates are flexible, but I have a company budget of 3100 USD. I'd like to go either in August or September.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 51,
#     'end_char_index': 55}]},
#  {'text': 'Great! And the time at which I will be departing from Mannheim to return to nyc?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 54,
#     'end_char_index': 62}]},
#  {'text': 'I would like a vacation for one in Mannheim from August 17 to September 7. My city of departure is Porto Alegre. It should cost less than $3000.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 139,
#     'end_char_index': 143},
#    {'entity_name': 'dst_city', 'start_char_index': 35, 'end_char_index': 43},
#    {'entity_name': 'or_city', 'start_char_index': 99, 'end_char_index': 111}]},
#  {'text': 'If I increase my budget to $6000, does that open up any options from August 17 to September 7?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 28,
#     'end_char_index': 32}]},
#  {'text': 'Are both of the packages to Porto still available if I bring my wife with me?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 33}]},
#  {'text': 'I was thinking maybe St. Louis',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 23}]},
#  {'text': "I will be departing from Tijuana. I'll be going solo",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 32}]},
#  {'text': 'what type of packages would i get if i were to go to Mannheim instead?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 53,
#     'end_char_index': 61}]},
#  {'text': 'im looking for a longer trip, would there perhaps be one in san antonio?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 60,
#     'end_char_index': 71}]},
#  {'text': 'Hi! I hear Hogsmeade has some excellent bars. Can you book me a trip there from Diagon Alley, leaving on August 13th? For 7 men and women',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 80,
#     'end_char_index': 92},
#    {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 20}]},
#  {'text': 'Well, we were thinking Dominican Republic could be fun as well.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 23,
#     'end_char_index': 41}]},
#  {'text': 'Yes, Vancouver.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 5,
#     'end_char_index': 14}]},
#  {'text': "Ok great! I'm looking for a trip from August 19th to September 3rd, and I'm thinking of going to Mexico City. I would be departing from Busan.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 136,
#     'end_char_index': 141},
#    {'entity_name': 'dst_city',
#     'start_char_index': 97,
#     'end_char_index': 108}]},
#  {'text': "I'll keep the second Mexico City option in mind. I have some other places that I'd like to consider.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 32}]},
#  {'text': 'What about Santo Domingo for the same dates?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 24}]},
#  {'text': "That sounds great to me. I have two other cities that I'd like to consider. Let's start with Toronto. What can you get me for the same dates with free breakfast?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 93,
#     'end_char_index': 100}]},
#  {'text': "Excellent. Can you see what's available in Athens?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 43,
#     'end_char_index': 49}]},
#  {'text': 'I can increase my budget by $200, does that open up any new options?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 29,
#     'end_char_index': 32}]},
#  {'text': 'Are there any other flights to Vancouver leaving  around the same time from another departure city?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 31,
#     'end_char_index': 40}]},
#  {'text': 'I would like to depart from Baltimore',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 28,
#     'end_char_index': 37}]},
#  {'text': 'hi I’m looking to go on a trip to Caprica',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 34,
#     'end_char_index': 41}]},
#  {'text': "Hi! I'd like to go to Boston from Mos Eisley on August 15th.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 44},
#    {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28}]},
#  {'text': 'Not Vancouver, anything for Porto Alegre?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 40}]},
#  {'text': 'What about if I leave from Rome instead of Mos Eisley?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 43,
#     'end_char_index': 53}]},
#  {'text': 'Hi im looking to make a quick trip im from tampa and want to go to Dallas',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 43,
#     'end_char_index': 48},
#    {'entity_name': 'dst_city', 'start_char_index': 67, 'end_char_index': 73}]},
#  {'text': 'Hi im from Leon and looking to get away',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 15}]},
#  {'text': 'Maybe milan',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 6,
#     'end_char_index': 11}]},
#  {'text': 'august 18th. until september 2nd',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 0,
#     'end_char_index': 9},
#    {'entity_name': 'end_date', 'start_char_index': 19, 'end_char_index': 30}]},
#  {'text': 'seems like Naples is a little too expensive what packages are there in Hamburg?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 71,
#     'end_char_index': 78}]},
#  {'text': "I'd like to go to Manaus from Miami between August 19th and September 2nd.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 30,
#     'end_char_index': 35},
#    {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 24}]},
#  {'text': "Perfect. I'd like to also compare the prices for a trip to Kobe between the same dates.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 59,
#     'end_char_index': 63}]},
#  {'text': "The Kobe package is considerably less expensive, I'll go with that one.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 4,
#     'end_char_index': 8}]},
#  {'text': 'I am one person voyaging to Tampa. I can depart from Indianapolis. Must be between 20th and 31 August.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 53,
#     'end_char_index': 65},
#    {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 33},
#    {'entity_name': 'str_date', 'start_char_index': 83, 'end_char_index': 85}]},
#  {'text': 'On second thought, I would like to go to Busan.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 41,
#     'end_char_index': 46}]},
#  {'text': "I'd like to go to Seattle from Belem between August 27th and September 5th. What is available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 31,
#     'end_char_index': 36},
#    {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 25}]},
#  {'text': 'That sounds good. What are my options if I leave from Belo Horizonte?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 54,
#     'end_char_index': 68}]},
#  {'text': 'Ok let me see, what about a trip to Paris leaving from Belem between the same dates?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 55,
#     'end_char_index': 60},
#    {'entity_name': 'dst_city', 'start_char_index': 36, 'end_char_index': 41}]},
#  {'text': 'What about Sao Paulo?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 20}]},
#  {'text': 'Travel to Sao Paulo.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 10,
#     'end_char_index': 19}]},
#  {'text': 'Fantastic! And if I leave from Belo Horizonte?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 31,
#     'end_char_index': 45}]},
#  {'text': 'Ok. I choose the trip to Seattle from Belem. What are the arrival and departure dates and times?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 32}]},
#  {'text': "Hi! I'm looking for a trip to Milan with two of my best friends for march break, what's available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 30,
#     'end_char_index': 35}]},
#  {'text': 'From Cleveland between Wednesday August 17 and Saturday August 27!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 5,
#     'end_char_index': 14}]},
#  {'text': 'What about Pittsburgh? It seems to be a trendy destination this year.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'Not at the moment, but i am from Mexico City',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 33,
#     'end_char_index': 44}]},
#  {'text': 'We want to go to Atlanta',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 17,
#     'end_char_index': 24}]},
#  {'text': 'We’re in Santa cruz!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 9,
#     'end_char_index': 19}]},
#  {'text': "I'd like to book a trip to Rome for business purposes. What's available for departures from Calgary?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 92,
#     'end_char_index': 99},
#    {'entity_name': 'dst_city', 'start_char_index': 27, 'end_char_index': 31}]},
#  {'text': 'To Paris. What can you offer around the same dates? Again, for two people.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 3,
#     'end_char_index': 8}]},
#  {'text': 'Great, and for leaving Paris?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 23,
#     'end_char_index': 28}]},
#  {'text': 'I am from London and am looking to book a vacation package!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 16}]},
#  {'text': 'are there any that go to San Diego?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 34}]},
#  {'text': 'hmmm I can only leave from London, what are the best options in Denver?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 27,
#     'end_char_index': 33},
#    {'entity_name': 'dst_city', 'start_char_index': 64, 'end_char_index': 70}]},
#  {'text': "let's see what we can do with something a bit further how about pittsburgh? what packages do we have there?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 64,
#     'end_char_index': 74}]},
#  {'text': 'anything after the 30th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 19,
#     'end_char_index': 21}]},
#  {'text': 'can we book the one that returns on the 18th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 40,
#     'end_char_index': 42}]},
#  {'text': 'I want to book a trip to Valencia!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 33}]},
#  {'text': 'I think i will be leaving from lima!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 31,
#     'end_char_index': 35}]},
#  {'text': 'Business it will be! those dates seem to fit in, I have to be back by september 11th! how much would  trip like that come out to?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 70,
#     'end_char_index': 82}]},
#  {'text': 'not yet, i was wondering what other options would i have in Punto cana.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 60,
#     'end_char_index': 70}]},
#  {'text': "I'd like to go to Mannheim for 8 days leaving from Paris. I have September 1 to September 19th off. What is available? This time, money isn't a problem, I'm treating myself. I'm looking for luxury this vacation.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 18,
#     'end_char_index': 26},
#    {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 56}]},
#  {'text': "That's exactly what I'm looking for! I'd also like to compare for trips to Porto Alegre. What can you offer?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 75,
#     'end_char_index': 87}]},
#  {'text': 'Hi. I need to book a vacation to Long Beach between August 25 and September 3. Departure is from Paris',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 97,
#     'end_char_index': 102},
#    {'entity_name': 'dst_city', 'start_char_index': 33, 'end_char_index': 43}]},
#  {'text': "I'm not quite sure I understand, is there anything available leaving Long Beach to go to Paris between August 25 and September 3rd?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 69,
#     'end_char_index': 79},
#    {'entity_name': 'dst_city', 'start_char_index': 89, 'end_char_index': 94}]},
#  {'text': 'No. I would like to leave Long Beach around the 25th of August to go to Paris for some reason. What is so confusing about that!?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 72,
#     'end_char_index': 77},
#    {'entity_name': 'dst_city', 'start_char_index': 72, 'end_char_index': 77}]},
#  {'text': "I live in Campinas, and I'd like to travel from August 25 the September 7. Let's start by looking at Vancouver!",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 18},
#    {'entity_name': 'dst_city',
#     'start_char_index': 101,
#     'end_char_index': 110}]},
#  {'text': 'Great! Now what about La Paz?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 28}]},
#  {'text': 'Can we take a look at trips to Kyoto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 31,
#     'end_char_index': 36}]},
#  {'text': 'Great! I also want to look at Puebla for the same dates.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 30,
#     'end_char_index': 36}]},
#  {'text': "The Puebla package is the cheapest, I'd like to know more about it. The hotel has how many stars?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 4,
#     'end_char_index': 10}]},
#  {'text': 'we’re getting married in San Jose and we want to leave on August 27th. we have already spent so much on the wedding and only have $2700 to sepnd',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 33},
#    {'entity_name': 'budget', 'start_char_index': 131, 'end_char_index': 135}]},
#  {'text': 'just myself!  im from North Vancouver',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 22,
#     'end_char_index': 37}]},
#  {'text': 'The police are after me, and I need to leave Kobe between August 27 and September 2.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 45,
#     'end_char_index': 49}]},
#  {'text': 'Take me anywhere, but I only have $4600 cash.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 35,
#     'end_char_index': 39}]},
#  {'text': "Hi we're from Miami and we want to go to paris, can you help out?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 14,
#     'end_char_index': 19},
#    {'entity_name': 'dst_city', 'start_char_index': 41, 'end_char_index': 46}]},
#  {'text': '$27500 is my budget',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 1,
#     'end_char_index': 6}]},
#  {'text': 'Hi im looking to go to Fukuoka',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 23,
#     'end_char_index': 30}]},
#  {'text': "Perhaps Toronto. We are currently in Rome for business, we'd like to leave from here. We're looking at going from August 18 to August 29th.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 37,
#     'end_char_index': 41},
#    {'entity_name': 'dst_city', 'start_char_index': 8, 'end_char_index': 15}]},
#  {'text': 'That sounds good. My husband loves Vancouver, can we take a look at some packages?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 35,
#     'end_char_index': 44}]},
#  {'text': 'From Rome please, and I have a preference for a hotel with a spa. If possible.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 5,
#     'end_char_index': 9}]},
#  {'text': 'In that case, how about Columbus?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 24,
#     'end_char_index': 32}]},
#  {'text': 'Ok, what about Calgary? My new boyfriend lives there.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 15,
#     'end_char_index': 22}]},
#  {'text': 'we want to leave on the 16th were looking to go to San Juan',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 24,
#     'end_char_index': 26},
#    {'entity_name': 'dst_city', 'start_char_index': 51, 'end_char_index': 59}]},
#  {'text': "We’re leaving from Godric's Hollow",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 19,
#     'end_char_index': 34}]},
#  {'text': 'we could leave from birmingham do you have anything from there?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 20,
#     'end_char_index': 30}]},
#  {'text': '$2,200',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 1,
#     'end_char_index': 2}]},
#  {'text': "I don't really have a preference for a destination, but I would like free breakfast. We would be leaving from Kingston for a vacation between August 19 and August 31.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 110,
#     'end_char_index': 118}]},
#  {'text': 'That sounds nice. My husband requested I stick to a budget of $25600. What is the price of this package?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 63,
#     'end_char_index': 68}]},
#  {'text': 'We were thinking of Fortaleza',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 20,
#     'end_char_index': 29}]},
#  {'text': 'We will be leaving from Santos',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 24,
#     'end_char_index': 30}]},
#  {'text': 'what options do you have in philadelphia, with the same dates?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 40}]},
#  {'text': "We'll be leaving from Goiania. Rosario is the place to be this year! Our spring break starts on August 28 and ends on September 4, can you find us something between those dates?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 22,
#     'end_char_index': 29},
#    {'entity_name': 'dst_city', 'start_char_index': 31, 'end_char_index': 38}]},
#  {'text': 'we are in Montreal',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 18}]},
#  {'text': 'we can leave from Birmingham',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 18,
#     'end_char_index': 28}]},
#  {'text': 'there is no budget at the moment. We are planning on going to paris',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 62,
#     'end_char_index': 67}]},
#  {'text': 'We need to find a vacation between August 26th and September 15th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 42,
#     'end_char_index': 44}]},
#  {'text': "Hi wozbot! My husband and I are recently married and madly in love. We're looking for a fantastic honeymoon vacation. We live in Mannheim and we'd like to go to Kyoto for 6 days leaving on August 19. What can you do for me?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 161,
#     'end_char_index': 166},
#    {'entity_name': 'or_city',
#     'start_char_index': 129,
#     'end_char_index': 137}]},
#  {'text': "This one sounds interesting, but I'd really like a vacation of 6 days, preferably leaving on the 19th of August. Can we take a look at Osaka?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 135,
#     'end_char_index': 140}]},
#  {'text': 'hi im from Coruscant looking to go to atlantis',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 20},
#    {'entity_name': 'dst_city', 'start_char_index': 38, 'end_char_index': 46}]},
#  {'text': 'i can leave from Kakariko Village does that work?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 17,
#     'end_char_index': 33}]},
#  {'text': 'HI im from Punta Cana can you help me find a vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'I want to get away for a bit! im from Houston',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 38,
#     'end_char_index': 45}]},
#  {'text': 'I live in Toronto, can we se what packages are available in Cairo from August 17 to September 7?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 17},
#    {'entity_name': 'dst_city', 'start_char_index': 60, 'end_char_index': 65}]},
#  {'text': 'Lets take a look at Pittsburgh as a destination!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 20,
#     'end_char_index': 30}]},
#  {'text': 'How about Leon?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 10,
#     'end_char_index': 14}]},
#  {'text': 'What about flights to La Paz from Toronto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 41},
#    {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28}]},
#  {'text': 'I have business in Calgary around those dates, what say I leave from Calgary, could I get a trip somewhere?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 19,
#     'end_char_index': 26}]},
#  {'text': 'Im leaving from Queenstown',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 16,
#     'end_char_index': 26}]},
#  {'text': 'HI there! my family and i are looking to go to Burlington',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 47,
#     'end_char_index': 57}]},
#  {'text': 'Campinnas',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 0,
#     'end_char_index': 9}]},
#  {'text': 'Hi im looking to book  trip. anything leaving from Kakariko Village?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 51,
#     'end_char_index': 67}]},
#  {'text': 'termina perhaps?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 0,
#     'end_char_index': 7}]},
#  {'text': 'Anything going to Caprica',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 18,
#     'end_char_index': 25}]},
#  {'text': "Good afternoon, my man! I'd like to plan a honeymoon in Naples for 5 days leaving from Madrid on August 17. What is available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 87,
#     'end_char_index': 93},
#    {'entity_name': 'dst_city', 'start_char_index': 56, 'end_char_index': 62}]},
#  {'text': 'Hi i want to plan my honeymoon to rome',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 34,
#     'end_char_index': 38}]},
#  {'text': 'i have a maximum budget of $3900',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 28,
#     'end_char_index': 32}]}]

# %% [markdown]
# # Création du Bot Fly Me

# %%
from azure.cognitiveservices.language.luis.authoring import LUISAuthoringClient
from azure.cognitiveservices.language.luis.authoring.models import ApplicationCreateObject
from azure.cognitiveservices.language.luis.runtime import LUISRuntimeClient
from msrest.authentication import CognitiveServicesCredentials
from functools import reduce

import json, time, uuid

authoringKey = '123007a9fbfb4ec2bd2e4cd7c88c37fa'
authoringEndpoint = 'https://languep10-authoring.cognitiveservices.azure.com/'
predictionKey = '75800c252f4246e9b665a9015f046091'
predictionEndpoint = 'https://langue-p10.cognitiveservices.azure.com/'


# We use a UUID to avoid name collisions.
appName = "Fly Me" + str(uuid.uuid4())
versionId = "0.1"
intentName = "FlyMe.Booking"



client = LUISAuthoringClient(authoringEndpoint, CognitiveServicesCredentials(authoringKey))

# define app basics
appDefinition = ApplicationCreateObject(name=appName, initial_version_id=versionId, culture='en-us')

# create app
app_id = client.apps.add(appDefinition)

# get app id - necessary for all other changes
print("Created LUIS app with ID {}".format(app_id))


client.model.add_intent(app_id, versionId, intentName)
# Out:
# Created LUIS app with ID 4928ce29-a4f8-4f8e-89b9-a04b0f4c63b2
# 'b5e6cbbd-246d-4066-bd61-618b457de6bd'

# %% [markdown]
# # Création des intentions

# %%
mlEntityDefinition = ['or_city', 'dst_city','str_date','end_date', 'budget']

[client.model.add_entity(app_id, versionId, name=Entity) for Entity in mlEntityDefinition]
# Out:
# ['33476b60-727a-464d-b266-c2b40246529d',
#  '0c879e92-24d1-492b-a1ff-07f39319b287',
#  'e68a3e24-4371-48b6-b4df-7685dce56a43',
#  '6464fb1b-ed5f-4105-9d7d-5c190bd01f8e',
#  '8ddd6742-1dbe-4b6d-ba7f-c723bce20b71']

# %% [markdown]
# # Envoi des examples de phrases avec entité

# %%
# Define labeled example

# Add an example for the entity.
# Enable nested children to allow using multiple models with the same name.
# The quantity subentity and the phraselist could have the same exact name if this is set to True
[client.examples.add(app_id, versionId, example) for example in labeledExampleUtteranceWithMLEntity]
# Out:
# [<azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f946fd0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f9791f0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f979370>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f979b80>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f973ee0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f973ca0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f973460>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f946f10>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1edd8730>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f942910>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f93aa90>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f979df0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f9796d0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f9794c0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7f8e1f9705b0>]

# %% [markdown]
# ## Focus sur les dates de retour

# %%
from bot import My_bot


def get_example_label(utterance, entity_name, value):
    """Build a EntityLabelObject.
    This will find the "value" start/end index in "utterance", and assign it to "entity name"
    """
    utterance = utterance.lower()
    value = value.lower()
    return {
        'entity_name': entity_name,
        'start_char_index': utterance.find(value),
        'end_char_index': utterance.find(value) + len(value)+2
    }



bot = My_bot()
labeledExampleUtteranceWithMLEntity = labeledExampleUtterance(df_end)
[bot.client.examples.add(bot.api_id, bot.versionId, example) for example in labeledExampleUtteranceWithMLEntity]
# Out:
# Getting runtime endpoint keys...
# Primary runtime endpoint key: a9399771-d190-42c3-a598-bc1aeaa405ea.
# [<azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb937edfa0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb23efb7f0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb23f02220>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb23f028b0>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb23f02e50>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb23f02c40>,
#  <azure.cognitiveservices.language.luis.authoring.models._models_py3.LabelExampleResponse at 0x7feb23f02850>]

# %%
labeledExampleUtteranceWithMLEntity
# Out:
# [{'text': 'I need to back by the 31st',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 22,
#     'end_char_index': 24}]},
#  {'text': 'Ya for sure, not sure where, lets see what would fit my plans between the 13th of august and the 16th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 97,
#     'end_char_index': 99}]},
#  {'text': 'maybe the 15th of August until the 20th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 35,
#     'end_char_index': 37}]},
#  {'text': 'august 18th. until september 2nd',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 19,
#     'end_char_index': 30}]},
#  {'text': 'can we book the one that returns on the 18th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 40,
#     'end_char_index': 42}]},
#  {'text': 'Business it will be! those dates seem to fit in, I have to be back by september 11th! how much would  trip like that come out to?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 70,
#     'end_char_index': 82}]},
#  {'text': 'We need to find a vacation between August 26th and September 15th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 42,
#     'end_char_index': 44}]}]

# %% [markdown]
# # Entrainement du modèle Luis

# %%
client.train.train_version(app_id, versionId)
waiting = True
while waiting:
    info = client.train.get_status(app_id, versionId)

    # get_status returns a list of training statuses, one for each model. Loop through them and make sure all are done.
    waiting = any(map(lambda x: 'Queued' == x.details.status or 'InProgress' == x.details.status, info))
    if waiting:
        print ("Waiting 10 seconds for training to complete...")
        time.sleep(10)
    else: 
        print ("trained")
        waiting = False
# Out:
# Waiting 10 seconds for training to complete...
# trained

# %% [markdown]
# # Publication & appel du model

# %%
client.apps.update_settings(app_id, is_public=True)

responseEndpointInfo = client.apps.publish(app_id, versionId, is_staging=False)

responseEndpointInfo

# %% [markdown]
# # Prediction

# %%
runtimeCredentials = CognitiveServicesCredentials(predictionKey)
clientRuntime = LUISRuntimeClient(endpoint=predictionEndpoint, credentials=runtimeCredentials)

# Production == slot name
predictionRequest = { "query" : "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700." }

predictionResponse = clientRuntime.prediction.get_slot_prediction(app_id, "Production", predictionRequest, show_all_intents=True)
print("Top intent: {}".format(predictionResponse.prediction.top_intent))
print("Sentiment: {}".format (predictionResponse.prediction.sentiment))
print("Intents: ")

for intent in predictionResponse.prediction.intents:
    print("\t{}".format (json.dumps (intent)))
print("Entities: {}".format (predictionResponse.prediction.entities))
# Out:
# Top intent: FlyMe.Booking
# Sentiment: None
# Intents:
# 	"FlyMe.Booking"
# 	"None"
# Entities: {'dst_city': ['Atlantis'], 'or_city': ['Caprica'], 'budget': ['1700.']}

# %% [markdown]
# # Scoring

# %%
data = collect_data(df, 80)
data
# Out:
#                                                    text     entit        val
# 0     I'd like to book a trip to Atlantis from Capri...    budget       1700
# 1     I'd like to book a trip to Atlantis from Capri...  dst_city   Atlantis
# 2     I'd like to book a trip to Atlantis from Capri...   or_city    Caprica
# 4     Yes, how about going to Neverland from Caprica...    budget       1900
# 5     Yes, how about going to Neverland from Caprica...  dst_city  Neverland
# ...                                                 ...       ...        ...
# 2293                          Anything going to Caprica  dst_city    Caprica
# 2295  Good afternoon, my man! I'd like to plan a hon...   or_city     Madrid
# 2296  Good afternoon, my man! I'd like to plan a hon...  dst_city     Naples
# 2309             Hi i want to plan my honeymoon to rome  dst_city       rome
# 2315                   i have a maximum budget of $3900    budget       3900
#
# [296 rows x 3 columns]

# %%
data_json = labeledExampleUtterance(data)
data_json
# Out:
# [{'text': "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 117,
#     'end_char_index': 121},
#    {'entity_name': 'dst_city', 'start_char_index': 27, 'end_char_index': 35},
#    {'entity_name': 'or_city', 'start_char_index': 41, 'end_char_index': 48}]},
#  {'text': 'Yes, how about going to Neverland from Caprica on August 13, 2016 for 5 adults. For this trip, my budget would be 1900.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 114,
#     'end_char_index': 118},
#    {'entity_name': 'dst_city', 'start_char_index': 24, 'end_char_index': 33},
#    {'entity_name': 'or_city', 'start_char_index': 39, 'end_char_index': 46}]},
#  {'text': 'I have no flexibility for dates... but I can leave from Atlantis rather than Caprica. How about that?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 56,
#     'end_char_index': 64},
#    {'entity_name': 'or_city', 'start_char_index': 56, 'end_char_index': 64}]},
#  {'text': 'Hello, I am looking to book a vacation from Gotham City to Mos Eisley for $2100.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 44,
#     'end_char_index': 55},
#    {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 69},
#    {'entity_name': 'budget', 'start_char_index': 75, 'end_char_index': 79}]},
#  {'text': 'What about a trip from Gotham City to Neverland for the same budget?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 23,
#     'end_char_index': 34},
#    {'entity_name': 'dst_city', 'start_char_index': 38, 'end_char_index': 47}]},
#  {'text': 'Would any packages to Mos Eisley be available if I increase my budget to $2500?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 32},
#    {'entity_name': 'budget', 'start_char_index': 74, 'end_char_index': 78}]},
#  {'text': "You know what, I'd like to try and visit Neverland",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 41,
#     'end_char_index': 50}]},
#  {'text': 'Do you have any trips from Gotham City to Kobe for my original budget of $2100?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 27,
#     'end_char_index': 38},
#    {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 46},
#    {'entity_name': 'budget', 'start_char_index': 74, 'end_char_index': 78}]},
#  {'text': "No, that's too far for me. I need a flight that leaves from Birmingham.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 60,
#     'end_char_index': 70}]},
#  {'text': 'How many days would I be in Kobe?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 32}]},
#  {'text': 'Hello there i am looking to go on a vacation with my family to Gotham City, can you help me?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 63,
#     'end_char_index': 74}]},
#  {'text': 'yes i do, it is around $2200',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 24,
#     'end_char_index': 28}]},
#  {'text': 'We are from Neverland',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 12,
#     'end_char_index': 21}]},
#  {'text': 'we can depart from Toronto',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 19,
#     'end_char_index': 26}]},
#  {'text': 'hmm what options would i have out of Toronto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 37,
#     'end_char_index': 44}]},
#  {'text': "Hi I'd like to go to Caprica from Busan, between Sunday August 21, 2016 and Wednesday August 31, 2016",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 39},
#    {'entity_name': 'dst_city', 'start_char_index': 21, 'end_char_index': 28}]},
#  {'text': 'Do you have anything for San Antonio as a destination?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 36}]},
#  {'text': 'Hello, I am looking to book a trip for 2 adults and 6 children for $21,300 or less. We are departing from Kochi for Denver.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 68,
#     'end_char_index': 70},
#    {'entity_name': 'dst_city', 'start_char_index': 116, 'end_char_index': 122},
#    {'entity_name': 'or_city',
#     'start_char_index': 106,
#     'end_char_index': 111}]},
#  {'text': 'I do not have any dates in mind. I would like to spend as much time in Denver as my budget will allow.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 71,
#     'end_char_index': 77}]},
#  {'text': 'Hey, i Want to go to St. Louis on the 17th of August',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 23}]},
#  {'text': 'I need to back by the 31st',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 22,
#     'end_char_index': 24}]},
#  {'text': 'I’m from Calgary',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 9,
#     'end_char_index': 16}]},
#  {'text': "I'm looking for a trip to Gotham City leaving from Kakariko Village on Saturday, August 13, 2016. 3 adults for no more than $2400 USD.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 125,
#     'end_char_index': 129},
#    {'entity_name': 'dst_city', 'start_char_index': 26, 'end_char_index': 37},
#    {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 67}]},
#  {'text': "I'd like to adjust the departure city to Caprica.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 41,
#     'end_char_index': 48}]},
#  {'text': 'The dates cannot be changed. How about going to Theed with 14 adults, leaving from Kakariko Village, on a budget of $2900?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 117,
#     'end_char_index': 121},
#    {'entity_name': 'dst_city', 'start_char_index': 48, 'end_char_index': 53},
#    {'entity_name': 'or_city', 'start_char_index': 83, 'end_char_index': 99}]},
#  {'text': 'Hello, I would like to book a 2-week trip leaving from Melbourne on August 27. I would like to go to Mannheim.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 55,
#     'end_char_index': 64},
#    {'entity_name': 'dst_city',
#     'start_char_index': 101,
#     'end_char_index': 109}]},
#  {'text': 'Is there a package to Mannheim which offers a cheaper hotel? I am flexible with my dates of arrival and departure.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 30}]},
#  {'text': 'What would the cost be if I stayed for 10 days in Mexico City?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 50,
#     'end_char_index': 61}]},
#  {'text': 'Actually I am leaving from Melbourne, Australia. How does this affect the price of the trip?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 27,
#     'end_char_index': 47}]},
#  {'text': 'Could I purchase a package  to Vancouver similar to the one I was offered?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 31,
#     'end_char_index': 40}]},
#  {'text': 'Hello, I am planning to book a trip to pittsborgh',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 39,
#     'end_char_index': 49}]},
#  {'text': 'We will be leaving from Fukuoka',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 24,
#     'end_char_index': 31}]},
#  {'text': 'I would like to see the availabilities in Vancouver please',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 42,
#     'end_char_index': 51}]},
#  {'text': 'I have $12600 to spend on this vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 8,
#     'end_char_index': 13}]},
#  {'text': 'Hi, I need to go to Mos Eisley for a wedding, leaving on Saturday, August 13, 2016 and returning on Tuesday, August 16, 2016. Preferably for $3700.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 20,
#     'end_char_index': 30},
#    {'entity_name': 'budget', 'start_char_index': 142, 'end_char_index': 146}]},
#  {'text': "I'd like to get away from Monday, August 15, 2016 to Wednesday, August 31, 2016. My budget is $3200 and I would leave from Detroit.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 123,
#     'end_char_index': 130},
#    {'entity_name': 'budget', 'start_char_index': 95, 'end_char_index': 99}]},
#  {'text': 'Good day, please book me a trip from Vancouver, Jamaica to Recife. I would like to leave for 17 days on August 24.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 37,
#     'end_char_index': 55},
#    {'entity_name': 'dst_city', 'start_char_index': 59, 'end_char_index': 65}]},
#  {'text': 'I would not like to travel to Vancouver, Canada.  Do you have any trips to Recife, Brazil?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 75,
#     'end_char_index': 89}]},
#  {'text': 'Actually I will be departing from Vancouver, British Columbia, do you have packages to Recife?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 61},
#    {'entity_name': 'dst_city', 'start_char_index': 87, 'end_char_index': 93}]},
#  {'text': 'Do you have any similar packages to Goiania?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 36,
#     'end_char_index': 43}]},
#  {'text': 'Actually I would like to purchase the first package to Recife.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 55,
#     'end_char_index': 61}]},
#  {'text': 'Hi im looking for a nice destination that i could go to from Columbus',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 61,
#     'end_char_index': 69}]},
#  {'text': 'Toronto seems like a better place this time of year, when would the flights be?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 0,
#     'end_char_index': 7}]},
#  {'text': "Hi, I have a big family and we can't afford a big vacation, we want to go to Atlantis from Mos Eisley for $3600 at most.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 91,
#     'end_char_index': 101},
#    {'entity_name': 'dst_city', 'start_char_index': 77, 'end_char_index': 85},
#    {'entity_name': 'budget', 'start_char_index': 107, 'end_char_index': 111}]},
#  {'text': 'No, we are visiting family in Atlantis. Can you check once more please?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 30,
#     'end_char_index': 38}]},
#  {'text': "Hi, I'm leaving from Diagon Alley and going to Coruscant on a budget of $3400. The dates don't matter, but I cannot afford anything over my budget.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 21,
#     'end_char_index': 33},
#    {'entity_name': 'dst_city', 'start_char_index': 47, 'end_char_index': 56},
#    {'entity_name': 'budget', 'start_char_index': 73, 'end_char_index': 77}]},
#  {'text': 'What about Neverland on the same budget?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 20}]},
#  {'text': 'nor Coruscant?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 4,
#     'end_char_index': 13}]},
#  {'text': 'Hi there, im from Vitoria and I want to go on vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 18,
#     'end_char_index': 25}]},
#  {'text': 'I would like to go to Santo domingo',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 35}]},
#  {'text': 'yes that sounds fine, looking to leave on the 19th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 46,
#     'end_char_index': 48}]},
#  {'text': 'Hi, me and my family want to take a trip to Kakariko Village.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 44,
#     'end_char_index': 60}]},
#  {'text': "We are four adults and 11 children departing from Godric's Hollow. $3500 is the most we are willing to spend.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 68,
#     'end_char_index': 72},
#    {'entity_name': 'or_city', 'start_char_index': 50, 'end_char_index': 65}]},
#  {'text': 'I would not be able to spend more than $4500',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 40,
#     'end_char_index': 44}]},
#  {'text': "We'll catch a flight from Toronto then. We're headed for Kakariko Village.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 57,
#     'end_char_index': 73},
#    {'entity_name': 'or_city', 'start_char_index': 26, 'end_char_index': 33}]},
#  {'text': 'Ok, do you have any travel packages to Kingston, Canada for 11 kids and 4 adults, $3500 or less, departing from Toronto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 83,
#     'end_char_index': 87},
#    {'entity_name': 'dst_city', 'start_char_index': 39, 'end_char_index': 55},
#    {'entity_name': 'or_city',
#     'start_char_index': 112,
#     'end_char_index': 119}]},
#  {'text': "Hi, I'm looking for a trip  from Thursday, August 18, 2016 to Thursday, September 8, 2016 to Mexico City",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 93,
#     'end_char_index': 104}]},
#  {'text': 'Kingston',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 0,
#     'end_char_index': 8}]},
#  {'text': "I prefer 3 stars and above. I'm flexible with my budget, is there anything else in Columbo?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 83,
#     'end_char_index': 90}]},
#  {'text': "That's looking good. I want to see a few more options before I choose one. There's nothing available in Porto?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 104,
#     'end_char_index': 109}]},
#  {'text': 'Porto would be great. Can you tell me more about the hotel.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 0,
#     'end_char_index': 5}]},
#  {'text': 'Hi im from Caprica looking to book a vacation to Hyrule',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 18},
#    {'entity_name': 'dst_city', 'start_char_index': 49, 'end_char_index': 55}]},
#  {'text': 'Ya for sure, not sure where, lets see what would fit my plans between the 13th of august and the 16th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 97,
#     'end_char_index': 99}]},
#  {'text': 'How about if i leave fro Birmingham?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 35}]},
#  {'text': "Hey man, imma leave from Godric's Hollow on August 27, 2016 and go to Goiania. Can't pay more than 4300USD. Watcha got?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 40},
#    {'entity_name': 'dst_city', 'start_char_index': 70, 'end_char_index': 77},
#    {'entity_name': 'budget', 'start_char_index': 99, 'end_char_index': 103}]},
#  {'text': 'yeah how about Montreal?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 15,
#     'end_char_index': 23}]},
#  {'text': 'HI im from Alexandria looking to book a 12 day vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'Hi im from termina can we find a vacation that starts on the 13th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 61,
#     'end_char_index': 63},
#    {'entity_name': 'or_city', 'start_char_index': 11, 'end_char_index': 18}]},
#  {'text': 'How about if i leave from Vancouver where would i be able to go?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 26,
#     'end_char_index': 35}]},
#  {'text': 'and if i were to leave from columbus?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 28,
#     'end_char_index': 36}]},
#  {'text': 'i have a budget of $3000, and let’s say that i leave from Mexico City',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 58,
#     'end_char_index': 69},
#    {'entity_name': 'budget', 'start_char_index': 20, 'end_char_index': 24}]},
#  {'text': "Hi. I'm looking for an adventure from Thursday, August 18 to Saturday, September 3. I'm thinking of going to Fortaleza. Yes, with free breakfast of course. I'm leaving from Essen.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 109,
#     'end_char_index': 118},
#    {'entity_name': 'or_city',
#     'start_char_index': 173,
#     'end_char_index': 178}]},
#  {'text': "Hi, my name is Harry Potter and I'd like to go to Hogsmeade leaving from Kakariko Village on Saturday, August 13th for 3 nights with 11 friends.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 50,
#     'end_char_index': 59},
#    {'entity_name': 'or_city', 'start_char_index': 73, 'end_char_index': 89}]},
#  {'text': "What? No. I'm looking for a trip to Hogsmeade with 11 of my friends.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 36,
#     'end_char_index': 45}]},
#  {'text': "Hi. I live in Busan and I'd like to go to Las Vegas from Wednesday August 17 to Monday September 5. What's available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 14,
#     'end_char_index': 19},
#    {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 51}]},
#  {'text': 'How much is a package to Punta Cana?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 35}]},
#  {'text': "I'd like to compare the Cairo and Punta Cana packages. What are the hotels, how many stars, free wifi, free breakfast?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 34,
#     'end_char_index': 44}]},
#  {'text': 'Hello, I want to leave from Seoul on August 27 and return on September 9. You can go to Manaus.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 28,
#     'end_char_index': 33},
#    {'entity_name': 'dst_city', 'start_char_index': 88, 'end_char_index': 94}]},
#  {'text': "I'm a polygamist and I'd like to travel with my 6 partners and 1 child to San Juan from Pittsburgh on a budget of 6600 USD",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 114,
#     'end_char_index': 118},
#    {'entity_name': 'dst_city', 'start_char_index': 74, 'end_char_index': 82},
#    {'entity_name': 'or_city', 'start_char_index': 88, 'end_char_index': 98}]},
#  {'text': "Ok I'll book the package with 8 days in Pittsburgh from August 17th to the 24th. Thank you.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 40,
#     'end_char_index': 50},
#    {'entity_name': 'or_city', 'start_char_index': 40, 'end_char_index': 50}]},
#  {'text': "Hi, send me on a 10 day-trip away from Cairo. I'd like to leave August 15. Send me to Sendai. Money is not object",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 86,
#     'end_char_index': 92},
#    {'entity_name': 'or_city', 'start_char_index': 39, 'end_char_index': 44}]},
#  {'text': "Good afternoon, I'd like to book a trip with my son from August 18 to August 29. He and I would be leaving from Curitiba. What destinations can you offer?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 112,
#     'end_char_index': 120}]},
#  {'text': 'Is there anything for 2600USD between the dates of August 18 and August 29th? For less than 10 days?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 22,
#     'end_char_index': 26}]},
#  {'text': 'Hi, my family and i are booking a trip to Sacramento, can you help us?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 42,
#     'end_char_index': 52}]},
#  {'text': 'we would be coming from San Diego',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 24,
#     'end_char_index': 33}]},
#  {'text': 'im willing to spend at most $4200',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 29,
#     'end_char_index': 33}]},
#  {'text': "Hi I need a break from Gotham City, the crime rate is just too high. I'd like to go to Hogsmead with 3 kids and 9 adults.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 23,
#     'end_char_index': 34},
#    {'entity_name': 'dst_city', 'start_char_index': 87, 'end_char_index': 95}]},
#  {'text': 'Hello, I have 15 vacation days available between June 1st and August 31st. I am leaving from Theed. I would like to go somewhere with lots of sunshine.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 93,
#     'end_char_index': 98},
#    {'entity_name': 'str_date', 'start_char_index': 14, 'end_char_index': 15}]},
#  {'text': 'Do you have any departures from Kobe, Japan?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 32,
#     'end_char_index': 43}]},
#  {'text': 'How about Birmingham City?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 25}]},
#  {'text': 'I can extend my vacation time to the 14th of September, does this open up any new options?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 37,
#     'end_char_index': 38}]},
#  {'text': "Hello! I live in Munich and I'd like to book any kind of trip between Monday, August 15th and Friday August 26th for 3 adults and 3 kids.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 17,
#     'end_char_index': 23}]},
#  {'text': 'Hi im from punta cana looking to go on a trip',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'Im thinking to Fukuoka',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 15,
#     'end_char_index': 22}]},
#  {'text': 'maybe the 15th of August until the 20th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 35,
#     'end_char_index': 37}]},
#  {'text': 'and what if i were to go to Essen?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 33}]},
#  {'text': 'these dates don’t look like they would be compatible with my schedule. Hey, how about going to hiroshima?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 95,
#     'end_char_index': 104}]},
#  {'text': 'Is there a flight to Santiago',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 29}]},
#  {'text': 'Hey! You can help me by finding a trip to Philadelphia from Maceio.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 60,
#     'end_char_index': 66},
#    {'entity_name': 'dst_city', 'start_char_index': 42, 'end_char_index': 54}]},
#  {'text': "Let's start with Philadelphia, how much is it I upgrade to business class?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 17,
#     'end_char_index': 29}]},
#  {'text': 'Good idea. What about Canoas?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 22,
#     'end_char_index': 28}]},
#  {'text': 'What about porto alegre',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 23}]},
#  {'text': "Good afternoon. I'd like to book a business trip to New York from Mannheim. What can you offer?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 66,
#     'end_char_index': 74},
#    {'entity_name': 'dst_city', 'start_char_index': 52, 'end_char_index': 60}]},
#  {'text': "Dates are flexible, but I have a company budget of 3100 USD. I'd like to go either in August or September.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 51,
#     'end_char_index': 55}]},
#  {'text': 'Great! And the time at which I will be departing from Mannheim to return to nyc?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 54,
#     'end_char_index': 62}]},
#  {'text': 'I would like a vacation for one in Mannheim from August 17 to September 7. My city of departure is Porto Alegre. It should cost less than $3000.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 139,
#     'end_char_index': 143},
#    {'entity_name': 'dst_city', 'start_char_index': 35, 'end_char_index': 43},
#    {'entity_name': 'or_city', 'start_char_index': 99, 'end_char_index': 111}]},
#  {'text': 'If I increase my budget to $6000, does that open up any options from August 17 to September 7?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 28,
#     'end_char_index': 32}]},
#  {'text': 'Are both of the packages to Porto still available if I bring my wife with me?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 33}]},
#  {'text': 'I was thinking maybe St. Louis',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 23}]},
#  {'text': "I will be departing from Tijuana. I'll be going solo",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 32}]},
#  {'text': 'what type of packages would i get if i were to go to Mannheim instead?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 53,
#     'end_char_index': 61}]},
#  {'text': 'im looking for a longer trip, would there perhaps be one in san antonio?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 60,
#     'end_char_index': 71}]},
#  {'text': 'Hi! I hear Hogsmeade has some excellent bars. Can you book me a trip there from Diagon Alley, leaving on August 13th? For 7 men and women',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 80,
#     'end_char_index': 92},
#    {'entity_name': 'dst_city', 'start_char_index': 11, 'end_char_index': 20}]},
#  {'text': 'Well, we were thinking Dominican Republic could be fun as well.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 23,
#     'end_char_index': 41}]},
#  {'text': 'Yes, Vancouver.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 5,
#     'end_char_index': 14}]},
#  {'text': "Ok great! I'm looking for a trip from August 19th to September 3rd, and I'm thinking of going to Mexico City. I would be departing from Busan.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 136,
#     'end_char_index': 141},
#    {'entity_name': 'dst_city',
#     'start_char_index': 97,
#     'end_char_index': 108}]},
#  {'text': "I'll keep the second Mexico City option in mind. I have some other places that I'd like to consider.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 21,
#     'end_char_index': 32}]},
#  {'text': 'What about Santo Domingo for the same dates?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 24}]},
#  {'text': "That sounds great to me. I have two other cities that I'd like to consider. Let's start with Toronto. What can you get me for the same dates with free breakfast?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 93,
#     'end_char_index': 100}]},
#  {'text': "Excellent. Can you see what's available in Athens?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 43,
#     'end_char_index': 49}]},
#  {'text': 'I can increase my budget by $200, does that open up any new options?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 29,
#     'end_char_index': 32}]},
#  {'text': 'Are there any other flights to Vancouver leaving  around the same time from another departure city?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 31,
#     'end_char_index': 40}]},
#  {'text': 'I would like to depart from Baltimore',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 28,
#     'end_char_index': 37}]},
#  {'text': 'hi I’m looking to go on a trip to Caprica',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 34,
#     'end_char_index': 41}]},
#  {'text': "Hi! I'd like to go to Boston from Mos Eisley on August 15th.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 44},
#    {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28}]},
#  {'text': 'Not Vancouver, anything for Porto Alegre?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 40}]},
#  {'text': 'What about if I leave from Rome instead of Mos Eisley?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 43,
#     'end_char_index': 53}]},
#  {'text': 'Hi im looking to make a quick trip im from tampa and want to go to Dallas',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 43,
#     'end_char_index': 48},
#    {'entity_name': 'dst_city', 'start_char_index': 67, 'end_char_index': 73}]},
#  {'text': 'Hi im from Leon and looking to get away',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 15}]},
#  {'text': 'Maybe milan',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 6,
#     'end_char_index': 11}]},
#  {'text': 'august 18th. until september 2nd',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 0,
#     'end_char_index': 9},
#    {'entity_name': 'end_date', 'start_char_index': 19, 'end_char_index': 30}]},
#  {'text': 'seems like Naples is a little too expensive what packages are there in Hamburg?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 71,
#     'end_char_index': 78}]},
#  {'text': "I'd like to go to Manaus from Miami between August 19th and September 2nd.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 30,
#     'end_char_index': 35},
#    {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 24}]},
#  {'text': "Perfect. I'd like to also compare the prices for a trip to Kobe between the same dates.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 59,
#     'end_char_index': 63}]},
#  {'text': "The Kobe package is considerably less expensive, I'll go with that one.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 4,
#     'end_char_index': 8}]},
#  {'text': 'I am one person voyaging to Tampa. I can depart from Indianapolis. Must be between 20th and 31 August.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 53,
#     'end_char_index': 65},
#    {'entity_name': 'dst_city', 'start_char_index': 28, 'end_char_index': 33},
#    {'entity_name': 'str_date', 'start_char_index': 83, 'end_char_index': 85}]},
#  {'text': 'On second thought, I would like to go to Busan.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 41,
#     'end_char_index': 46}]},
#  {'text': "I'd like to go to Seattle from Belem between August 27th and September 5th. What is available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 31,
#     'end_char_index': 36},
#    {'entity_name': 'dst_city', 'start_char_index': 18, 'end_char_index': 25}]},
#  {'text': 'That sounds good. What are my options if I leave from Belo Horizonte?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 54,
#     'end_char_index': 68}]},
#  {'text': 'Ok let me see, what about a trip to Paris leaving from Belem between the same dates?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 55,
#     'end_char_index': 60},
#    {'entity_name': 'dst_city', 'start_char_index': 36, 'end_char_index': 41}]},
#  {'text': 'What about Sao Paulo?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 20}]},
#  {'text': 'Travel to Sao Paulo.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 10,
#     'end_char_index': 19}]},
#  {'text': 'Fantastic! And if I leave from Belo Horizonte?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 31,
#     'end_char_index': 45}]},
#  {'text': 'Ok. I choose the trip to Seattle from Belem. What are the arrival and departure dates and times?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 32}]},
#  {'text': "Hi! I'm looking for a trip to Milan with two of my best friends for march break, what's available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 30,
#     'end_char_index': 35}]},
#  {'text': 'From Cleveland between Wednesday August 17 and Saturday August 27!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 5,
#     'end_char_index': 14}]},
#  {'text': 'What about Pittsburgh? It seems to be a trendy destination this year.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'Not at the moment, but i am from Mexico City',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 33,
#     'end_char_index': 44}]},
#  {'text': 'We want to go to Atlanta',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 17,
#     'end_char_index': 24}]},
#  {'text': 'We’re in Santa cruz!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 9,
#     'end_char_index': 19}]},
#  {'text': "I'd like to book a trip to Rome for business purposes. What's available for departures from Calgary?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 92,
#     'end_char_index': 99},
#    {'entity_name': 'dst_city', 'start_char_index': 27, 'end_char_index': 31}]},
#  {'text': 'To Paris. What can you offer around the same dates? Again, for two people.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 3,
#     'end_char_index': 8}]},
#  {'text': 'Great, and for leaving Paris?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 23,
#     'end_char_index': 28}]},
#  {'text': 'I am from London and am looking to book a vacation package!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 16}]},
#  {'text': 'are there any that go to San Diego?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 34}]},
#  {'text': 'hmmm I can only leave from London, what are the best options in Denver?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 27,
#     'end_char_index': 33},
#    {'entity_name': 'dst_city', 'start_char_index': 64, 'end_char_index': 70}]},
#  {'text': "let's see what we can do with something a bit further how about pittsburgh? what packages do we have there?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 64,
#     'end_char_index': 74}]},
#  {'text': 'anything after the 30th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 19,
#     'end_char_index': 21}]},
#  {'text': 'can we book the one that returns on the 18th?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 40,
#     'end_char_index': 42}]},
#  {'text': 'I want to book a trip to Valencia!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 25,
#     'end_char_index': 33}]},
#  {'text': 'I think i will be leaving from lima!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 31,
#     'end_char_index': 35}]},
#  {'text': 'Business it will be! those dates seem to fit in, I have to be back by september 11th! how much would  trip like that come out to?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 70,
#     'end_char_index': 82}]},
#  {'text': 'not yet, i was wondering what other options would i have in Punto cana.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 60,
#     'end_char_index': 70}]},
#  {'text': "I'd like to go to Mannheim for 8 days leaving from Paris. I have September 1 to September 19th off. What is available? This time, money isn't a problem, I'm treating myself. I'm looking for luxury this vacation.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 18,
#     'end_char_index': 26},
#    {'entity_name': 'or_city', 'start_char_index': 51, 'end_char_index': 56}]},
#  {'text': "That's exactly what I'm looking for! I'd also like to compare for trips to Porto Alegre. What can you offer?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 75,
#     'end_char_index': 87}]},
#  {'text': 'Hi. I need to book a vacation to Long Beach between August 25 and September 3. Departure is from Paris',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 97,
#     'end_char_index': 102},
#    {'entity_name': 'dst_city', 'start_char_index': 33, 'end_char_index': 43}]},
#  {'text': "I'm not quite sure I understand, is there anything available leaving Long Beach to go to Paris between August 25 and September 3rd?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 69,
#     'end_char_index': 79},
#    {'entity_name': 'dst_city', 'start_char_index': 89, 'end_char_index': 94}]},
#  {'text': 'No. I would like to leave Long Beach around the 25th of August to go to Paris for some reason. What is so confusing about that!?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 72,
#     'end_char_index': 77},
#    {'entity_name': 'dst_city', 'start_char_index': 72, 'end_char_index': 77}]},
#  {'text': "I live in Campinas, and I'd like to travel from August 25 the September 7. Let's start by looking at Vancouver!",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 18},
#    {'entity_name': 'dst_city',
#     'start_char_index': 101,
#     'end_char_index': 110}]},
#  {'text': 'Great! Now what about La Paz?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 22,
#     'end_char_index': 28}]},
#  {'text': 'Can we take a look at trips to Kyoto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 31,
#     'end_char_index': 36}]},
#  {'text': 'Great! I also want to look at Puebla for the same dates.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 30,
#     'end_char_index': 36}]},
#  {'text': "The Puebla package is the cheapest, I'd like to know more about it. The hotel has how many stars?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 4,
#     'end_char_index': 10}]},
#  {'text': 'we’re getting married in San Jose and we want to leave on August 27th. we have already spent so much on the wedding and only have $2700 to sepnd',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 25,
#     'end_char_index': 33},
#    {'entity_name': 'budget', 'start_char_index': 131, 'end_char_index': 135}]},
#  {'text': 'just myself!  im from North Vancouver',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 22,
#     'end_char_index': 37}]},
#  {'text': 'The police are after me, and I need to leave Kobe between August 27 and September 2.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 45,
#     'end_char_index': 49}]},
#  {'text': 'Take me anywhere, but I only have $4600 cash.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 35,
#     'end_char_index': 39}]},
#  {'text': "Hi we're from Miami and we want to go to paris, can you help out?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 14,
#     'end_char_index': 19},
#    {'entity_name': 'dst_city', 'start_char_index': 41, 'end_char_index': 46}]},
#  {'text': '$27500 is my budget',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 1,
#     'end_char_index': 6}]},
#  {'text': 'Hi im looking to go to Fukuoka',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 23,
#     'end_char_index': 30}]},
#  {'text': "Perhaps Toronto. We are currently in Rome for business, we'd like to leave from here. We're looking at going from August 18 to August 29th.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 37,
#     'end_char_index': 41},
#    {'entity_name': 'dst_city', 'start_char_index': 8, 'end_char_index': 15}]},
#  {'text': 'That sounds good. My husband loves Vancouver, can we take a look at some packages?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 35,
#     'end_char_index': 44}]},
#  {'text': 'From Rome please, and I have a preference for a hotel with a spa. If possible.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 5,
#     'end_char_index': 9}]},
#  {'text': 'In that case, how about Columbus?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 24,
#     'end_char_index': 32}]},
#  {'text': 'Ok, what about Calgary? My new boyfriend lives there.',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 15,
#     'end_char_index': 22}]},
#  {'text': 'we want to leave on the 16th were looking to go to San Juan',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'str_date',
#     'start_char_index': 24,
#     'end_char_index': 26},
#    {'entity_name': 'dst_city', 'start_char_index': 51, 'end_char_index': 59}]},
#  {'text': "We’re leaving from Godric's Hollow",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 19,
#     'end_char_index': 34}]},
#  {'text': 'we could leave from birmingham do you have anything from there?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 20,
#     'end_char_index': 30}]},
#  {'text': '$2,200',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 1,
#     'end_char_index': 2}]},
#  {'text': "I don't really have a preference for a destination, but I would like free breakfast. We would be leaving from Kingston for a vacation between August 19 and August 31.",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 110,
#     'end_char_index': 118}]},
#  {'text': 'That sounds nice. My husband requested I stick to a budget of $25600. What is the price of this package?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 63,
#     'end_char_index': 68}]},
#  {'text': 'We were thinking of Fortaleza',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 20,
#     'end_char_index': 29}]},
#  {'text': 'We will be leaving from Santos',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 24,
#     'end_char_index': 30}]},
#  {'text': 'what options do you have in philadelphia, with the same dates?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 28,
#     'end_char_index': 40}]},
#  {'text': "We'll be leaving from Goiania. Rosario is the place to be this year! Our spring break starts on August 28 and ends on September 4, can you find us something between those dates?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 22,
#     'end_char_index': 29},
#    {'entity_name': 'dst_city', 'start_char_index': 31, 'end_char_index': 38}]},
#  {'text': 'we are in Montreal',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 18}]},
#  {'text': 'we can leave from Birmingham',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 18,
#     'end_char_index': 28}]},
#  {'text': 'there is no budget at the moment. We are planning on going to paris',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 62,
#     'end_char_index': 67}]},
#  {'text': 'We need to find a vacation between August 26th and September 15th',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'end_date',
#     'start_char_index': 42,
#     'end_char_index': 44}]},
#  {'text': "Hi wozbot! My husband and I are recently married and madly in love. We're looking for a fantastic honeymoon vacation. We live in Mannheim and we'd like to go to Kyoto for 6 days leaving on August 19. What can you do for me?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 161,
#     'end_char_index': 166},
#    {'entity_name': 'or_city',
#     'start_char_index': 129,
#     'end_char_index': 137}]},
#  {'text': "This one sounds interesting, but I'd really like a vacation of 6 days, preferably leaving on the 19th of August. Can we take a look at Osaka?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 135,
#     'end_char_index': 140}]},
#  {'text': 'hi im from Coruscant looking to go to atlantis',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 20},
#    {'entity_name': 'dst_city', 'start_char_index': 38, 'end_char_index': 46}]},
#  {'text': 'i can leave from Kakariko Village does that work?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 17,
#     'end_char_index': 33}]},
#  {'text': 'HI im from Punta Cana can you help me find a vacation',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 11,
#     'end_char_index': 21}]},
#  {'text': 'I want to get away for a bit! im from Houston',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 38,
#     'end_char_index': 45}]},
#  {'text': 'I live in Toronto, can we se what packages are available in Cairo from August 17 to September 7?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 10,
#     'end_char_index': 17},
#    {'entity_name': 'dst_city', 'start_char_index': 60, 'end_char_index': 65}]},
#  {'text': 'Lets take a look at Pittsburgh as a destination!',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 20,
#     'end_char_index': 30}]},
#  {'text': 'How about Leon?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 10,
#     'end_char_index': 14}]},
#  {'text': 'What about flights to La Paz from Toronto?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 34,
#     'end_char_index': 41},
#    {'entity_name': 'dst_city', 'start_char_index': 22, 'end_char_index': 28}]},
#  {'text': 'I have business in Calgary around those dates, what say I leave from Calgary, could I get a trip somewhere?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 19,
#     'end_char_index': 26}]},
#  {'text': 'Im leaving from Queenstown',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 16,
#     'end_char_index': 26}]},
#  {'text': 'HI there! my family and i are looking to go to Burlington',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 47,
#     'end_char_index': 57}]},
#  {'text': 'Campinnas',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 0,
#     'end_char_index': 9}]},
#  {'text': 'Hi im looking to book  trip. anything leaving from Kakariko Village?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 51,
#     'end_char_index': 67}]},
#  {'text': 'termina perhaps?',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 0,
#     'end_char_index': 7}]},
#  {'text': 'Anything going to Caprica',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 18,
#     'end_char_index': 25}]},
#  {'text': "Good afternoon, my man! I'd like to plan a honeymoon in Naples for 5 days leaving from Madrid on August 17. What is available?",
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'or_city',
#     'start_char_index': 87,
#     'end_char_index': 93},
#    {'entity_name': 'dst_city', 'start_char_index': 56, 'end_char_index': 62}]},
#  {'text': 'Hi i want to plan my honeymoon to rome',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'dst_city',
#     'start_char_index': 34,
#     'end_char_index': 38}]},
#  {'text': 'i have a maximum budget of $3900',
#   'intentName': 'FlyMe.Booking',
#   'entityLabels': [{'entity_name': 'budget',
#     'start_char_index': 28,
#     'end_char_index': 32}]}]

# %%
# Séparation en jeu d'entrainement et test
from sklearn.model_selection import train_test_split

X_train , X_test = train_test_split(data_json)

len(X_train), len(X_test)
# Out:
# (164, 55)

# %%
# Publication des phrases example de X
for example in X_train:
    try:
        client.examples.add(app_id, versionId, example)
    except :
        pass

# %%
# Entrainement
client.train.train_version(app_id, versionId)
waiting = True
while waiting:
    info = client.train.get_status(app_id, versionId)

    # get_status returns a list of training statuses, one for each model. Loop through them and make sure all are done.
    waiting = any(map(lambda x: 'Queued' == x.details.status or 'InProgress' == x.details.status, info))
    if waiting:
        print ("Waiting 10 seconds for training to complete...")
        time.sleep(10)
    else: 
        print ("trained")
        waiting = False
        
# Publication       
client.apps.update_settings(app_id, is_public=True)
responseEndpointInfo = client.apps.publish(app_id, versionId, is_staging=False)
# Out:
# Waiting 10 seconds for training to complete...
# trained

# %%
def luis_score(X):
    score = []
    for x in X:
        predictionRequest = { "query" : x['text']}
        
        predictionResponse = clientRuntime.prediction.get_slot_prediction(app_id, 
                                                                          "Production", 
                                                                          predictionRequest, 
                                                                          show_all_intents=True)
        
        score.append(predictionResponse.prediction.intents['FlyMe.Booking'].score)
    return np.array(score).mean()

# %%
luis_score(X_train)
# Out:
# 0.998857898109756

# %%
luis_score(X_test)
# Out:
# 0.9814074969345454

# %% [markdown]
# # Création d'un pipline de transformation

# %%
from azure.cognitiveservices.language.luis.authoring import LUISAuthoringClient
from azure.cognitiveservices.language.luis.authoring.models import ApplicationCreateObject
from azure.cognitiveservices.language.luis.runtime import LUISRuntimeClient
from msrest.authentication import CognitiveServicesCredentials
from functools import reduce

import json, time, uuid


class My_bot():
    def __init__(self, name):
        self.authoringKey = '123007a9fbfb4ec2bd2e4cd7c88c37fa'
        self.authoringEndpoint = 'https://languep10-authoring.cognitiveservices.azure.com/'
        self.predictionKey = '75800c252f4246e9b665a9015f046091'
        self.predictionEndpoint = 'https://langue-p10.cognitiveservices.azure.com/'
        
        # We use a UUID to avoid name collisions.
        self.appName = name + str(uuid.uuid4())
        self.versionId = "0.1"
        self.intentName = "FlyMe.Booking"
        
        self.client = LUISAuthoringClient(self.authoringEndpoint, 
                                          CognitiveServicesCredentials(self.authoringKey))

        # define app basics
        self.appDefinition = ApplicationCreateObject(name=self.appName, 
                                                     initial_version_id=self.versionId, culture='en-us')

        # create app
        self.app_id = self.client.apps.add(self.appDefinition)

        # get app id - necessary for all other changes
        print("Created LUIS app with ID {}".format(self.app_id))


        self.client.model.add_intent(self.app_id, self.versionId, self.intentName)

    def add_entity(self, mlEntityDefinition = ['or_city', 'dst_city','str_date','end_date','budget']):
        [self.client.model.add_entity(self.app_id, self.versionId, name=Entity) 
         for Entity in mlEntityDefinition]
        
        
        
    def collect_data(self, df, n=10):
        
        self.add_entity()
        # Création d'une liste des textes accompagnés de leurs entités 
        base_data = []

        # Sélection de n conversation du jeu de données
        for i in range(n):
            # Filtrage des réponses du bot
            data = [u for u in df[i]['turns'] if 'db' not in u.keys()]

            # Récupération des messages utilisateur avec leurs entités
            for messages in data: 
                text = messages['text']
                info = messages['labels']['frames'][-1]['info']
                [base_data.append((text, u,info[u][0]['val'])) 
                 for u in info.keys() if u in mlEntityDefinition]

        # Création d'un dataframe contenant le text l'entité et la valeur de l'entité
        base_data = pd.DataFrame(base_data, columns=['text', 'entit', 'val'])
        base_data.val = base_data.val.apply(lambda x: x.split('.')[0])

        # Filtre permettant de ne conserver uniquement les entité présent dans le text
        filtre = [base_data.val.values[n] in base_data.text.values[n] for n in range(len(base_data))]

        self.base_data = base_data[filtre]

        return base_data[filtre]

    # Fonction permettant de sortir le jeu de données sous format 
    #json en vu d'interpretation par le model Luois
    def labeledExampleUtterance(self,n=10, intentName = "FlyMe.Booking"):

        self.collect_data(df, n)
        data = self.base_data
        def get_example_label(utterance, entity_name, value):
            """Build a EntityLabelObject.
            This will find the "value" start/end index in "utterance", and assign it to "entity name"
            """
            utterance = utterance.lower()
            value = value.lower()
            return {
                'entity_name': entity_name,
                'start_char_index': utterance.find(value),
                'end_char_index': utterance.find(value) + len(value)
            }

        data_Uterance = []
        for text in data.text.unique():
            data_temp = data[data.text == text][['entit','val']]
            data_json = {
                "text": text,
                "intentName": intentName,
                "entityLabels": [get_example_label(text, data_temp.entit.iloc[n], data_temp.val.iloc[n]) 
                                 for n in range(len(data_temp))]
            }
            data_Uterance.append(data_json)
            
        self.utterance = data_Uterance

        for example in  self.utterance:
            try :
                client.examples.add(self.app_id, self.versionId, example)
            except : pass
        print('Example published')
        
        
    def train(self):
        self.client.train.train_version(self.app_id, self.versionId)
        waiting = True
        while waiting:
            info = self.client.train.get_status(self.app_id, self.versionId)

            # get_status returns a list of training statuses, one for each model. 
            #Loop through them and make sure all are done.
            waiting = any(map(lambda x: 'Queued' == x.details.status or 'InProgress' == x.details.status, 
                              info))
            if waiting:
                print ("Waiting 10 seconds for training to complete...")
                time.sleep(10)
            else: 
                print ("trained")
                waiting = False
        
        time.sleep(5)
        self.client.apps.update_settings(self.app_id, is_public=True)
        self.responseEndpointInfo = self.client.apps.publish(self.app_id, self.versionId, is_staging=False)
        
        
        
    def prediction(self, text):
        self.runtimeCredentials = CognitiveServicesCredentials(self.predictionKey)
        self.clientRuntime = LUISRuntimeClient(endpoint=predictionEndpoint, credentials=runtimeCredentials)

        # Production == slot name
        self.predictionRequest = { "query" : text}

        self.predictionResponse = self.clientRuntime.prediction.get_slot_prediction(app_id, "Production", predictionRequest, show_all_intents=True)
        print("Top intent: {}".format(predictionResponse.prediction.top_intent))
        print("Sentiment: {}".format (predictionResponse.prediction.sentiment))
        print("Intents: ")

        for intent in self.predictionResponse.prediction.intents:
            print("\t{}".format (json.dumps (intent)))
        print("Entities: {}".format (predictionResponse.prediction.entities))
        
        return predictionResponse.prediction.entities
        
    
    def luis_score(X):
        score = []
        for x in X:
            predictionRequest = { "query" : x['text']}

            predictionResponse = clientRuntime.prediction.get_slot_prediction(app_id, 
                                                                              "Production", 
                                                                              predictionRequest, 
                                                                              show_all_intents=True)

            score.append(predictionResponse.prediction.intents['FlyMe.Booking'].score)
        return np.array(score).mean()

# %%
bot = My_bot()
# Out:
# Created LUIS app with ID 67f94d39-f109-4f68-b962-00c7b39ec2e5

# %%
bot.labeledExampleUtterance(1)

# %%
from azure.cognitiveservices.language.luis.authoring.models import ApplicationInfoResponse

# %%
class My_bot():
    def __init__(self, name):
        self.authoringKey = '123007a9fbfb4ec2bd2e4cd7c88c37fa'
        self.authoringEndpoint = 'https://languep10-authoring.cognitiveservices.azure.com/'
        self.predictionKey = '75800c252f4246e9b665a9015f046091'
        self.predictionEndpoint = 'https://langue-p10.cognitiveservices.azure.com/'
        
        # We use a UUID to avoid name collisions.
        self.appName = name + str(uuid.uuid4())
        self.versionId = "0.1"
        self.intentName = "FlyMe.Booking"
        
        self.client = LUISAuthoringClient(self.authoringEndpoint, 
                                          CognitiveServicesCredentials(self.authoringKey))

        # define app basics
        self.appDefinition = ApplicationCreateObject(name=self.appName, 
                                                     initial_version_id=self.versionId, culture='en-us')

        # create app
        self.app_id = self.client.apps.add(self.appDefinition)

        # get app id - necessary for all other changes
        print("Created LUIS app with ID {}".for

# %%
class My_bot():
    def __init__(self, api_id):
        self.authoringKey = '123007a9fbfb4ec2bd2e4cd7c88c37fa'
        self.authoringEndpoint = 'https://languep10-authoring.cognitiveservices.azure.com/'
        self.predictionKey = '75800c252f4246e9b665a9015f046091'
        self.predictionEndpoint = 'https://langue-p10.cognitiveservices.azure.com/'
        
        # We use a UUID to avoid name collisions.
        self.versionId = "0.1"
        self.intentName = "FlyMe.Booking"
        
        self.client = LUISAuthoringClient(self.authoringEndpoint, 
                                          CognitiveServicesCredentials(self.authoringKey))
        
        self.runtimeCredentials = CognitiveServicesCredentials(self.predictionKey)
        self.clientRuntime = LUISRuntimeClient(endpoint=predictionEndpoint, credentials=runtimeCredentials)

        # create app
        self.app_id = api_id
        
        self.data = {
            'or_city': False, 
              'dst_city': False,
              'str_date': False,
              'end_date': False,
              'budget': False
             }

    def check_reponse(sel, rep):
    
        for k in rep.keys():
            self.data[k] = rep[k]

        data_lost = []
        for k in self.data.keys():
            if self.data[k] == False:
                data_lost.append(k)

        return data_lost, len(data_lost)

    def prediction(self, text):
        
        def check_reponse(rep):
    
            for k in rep.keys():
                self.data[k] = rep[k]

            data_lost = []
            for k in self.data.keys():
                if self.data[k] == False:
                    data_lost.append(k)

            return data_lost, len(data_lost)

        
        

        # Production == slot name
        self.predictionRequest = { "query" : text}

        predictionResponse = self.clientRuntime.prediction.get_slot_prediction(self.app_id, 
                                                                                    "Production", 
                                                                                    self.predictionRequest, 
                                                                                    show_all_intents=True)
        
        
        print("Top intent: {}".format(predictionResponse.prediction.top_intent))
        print("Sentiment: {}".format (predictionResponse.prediction.sentiment))
        print("Intents: ")

        for intent in predictionResponse.prediction.intents:
            print("\t{}".format (json.dumps (intent)))
        print("Entities: {}".format (predictionResponse.prediction.entities))
        
        

        rep = predictionResponse.prediction.entities
        check_reponse(rep)
        return predictionResponse.prediction.entities

# %%
bot = My_bot('9b0fd8a7-81ed-402c-a2a0-b534ee7d78cf')

# %%
bot.prediction('Hello, from Paris to Madrid')
# Out:
# Top intent: FlyMe.Booking
# Sentiment: None
# Intents:
# 	"FlyMe.Booking"
# 	"None"
# Entities: {'or_city': ['Paris'], 'dst_city': ['Madrid']}
# {'or_city': ['Paris'], 'dst_city': ['Madrid']}

# %%
bot.data
# Out:
# {'or_city': ['Paris'],
#  'dst_city': ['Madrid'],
#  'str_date': False,
#  'end_date': False,
#  'budget': False}

# %%
BOT = My_bot('BotProd')
# Out:
# Created LUIS app with ID 9b0fd8a7-81ed-402c-a2a0-b534ee7d78cf

# %%
BOT.labeledExampleUtterance()
# Out:
# Example published

# %%
BOT.train()
# Out:
# Waiting 10 seconds for training to complete...
# trained

# %%
rep = BOT.prediction('Hi, paris to madrid')
# Out:
# Top intent: FlyMe.Booking
# Sentiment: None
# Intents:
# 	"FlyMe.Booking"
# 	"None"
# Entities: {'dst_city': ['Atlantis'], 'or_city': ['Caprica'], 'budget': ['1700.']}

# %%
rep = {'dst_city': ['Atlantis'], 'or_city': ['Caprica'], 'budget': ['1700.']}



d_ = {'or_city': False, 
      'dst_city': False,
      'str_date': False,
      'end_date': False,
      'budget': False
     }

# %%
for k in d.keys():
    d_[k] = rep[k]

# %%
def check_reponse(sel, rep, d_):
    
    for k in d.keys():
        d_[k] = rep[k]
    
    data_lost = []
    for k in d_.keys():
        if d_[k] == False:
            data_lost.append(k)
            
    self.data = d_
    return data_lost, len(data_lost)

# %% [markdown]
# # Création d'une base de connaissance

# %%
import os
import time

from azure.cognitiveservices.knowledge.qnamaker.authoring import QnAMakerClient
from azure.cognitiveservices.knowledge.qnamaker.runtime import QnAMakerRuntimeClient
from azure.cognitiveservices.knowledge.qnamaker.authoring.models import QnADTO, MetadataDTO, CreateKbDTO, OperationStateType, UpdateKbOperationDTO, UpdateKbOperationDTOAdd, EndpointKeysDTO, QnADTOContext, PromptDTO
from azure.cognitiveservices.knowledge.qnamaker.runtime.models import QueryDTO
from msrest.authentication import CognitiveServicesCredentials

# %%
subscription_key = 'cbb4bcaa0a334e02a1261cf18aa1ad18'

authoring_endpoint = 'https://qna0.cognitiveservices.azure.com/'

runtime_endpoint = 'https://qna0.azurewebsites.net'


client = QnAMakerClient(endpoint=authoring_endpoint, credentials=CognitiveServicesCredentials(subscription_key))

# %%
def _monitor_operation(client, operation):

    for i in range(20):
        if operation.operation_state in [OperationStateType.not_started, OperationStateType.running]:
            print("Waiting for operation: {} to complete.".format(operation.operation_id))
            time.sleep(5)
            operation = client.operations.get_details(operation_id=operation.operation_id)
        else:
            break
    if operation.operation_state != OperationStateType.succeeded:
        raise Exception("Operation {} failed to complete.".format(operation.operation_id))

    return operation

# %%
print(f"La première conversation contient {len(df[0]['turns'])} échanges.")

[(u['author'],u['text']) for u in df[0]['turns']]
# Out:
# La première conversation contient 7 échanges.
# [('user',
#   "I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700."),
#  ('wizard',
#   'Hi...I checked a few options for you, and unfortunately, we do not currently have any trips that meet this criteria.  Would you like to book an alternate travel option?'),
#  ('user',
#   'Yes, how about going to Neverland from Caprica on August 13, 2016 for 5 adults. For this trip, my budget would be 1900.'),
#  ('wizard',
#   'I checked the availability for this date and there were no trips available.  Would you like to select some alternate dates?'),
#  ('user',
#   'I have no flexibility for dates... but I can leave from Atlantis rather than Caprica. How about that?'),
#  ('wizard',
#   'I checked the availability for that date and there were no trips available.  Would you like to select some alternate dates?'),
#  ('user',
#   "I suppose I'll speak with my husband to see if we can choose other dates, and then I'll come back to you.Thanks for your help")]

# %%
def export_qna(df, n):
    qna = []

    for i in range(n):
        user = []
        wizard = []

        for u in df[i]['turns']:
            if u['author'] == 'user':
                user.append(u['text'])
            elif u['author'] == 'wizard':
                wizard.append(u['text'])
        df_conv = pd.DataFrame(user, columns=['Question'])
        df_conv['Answer'] = pd.DataFrame(wizard)
        qna.append(df_conv)
        
    return qna

# %%
qna = export_qna(df, 10)
qna[2]
# Out:
#                                              Question  \
# 0   Hello there i am looking to go on a vacation w...
# 1   Not sure when we want to leave, but we are 12 ...
# 2                        yes i do, it is around $2200
# 3                               We are from Neverland
# 4                          we can depart from Toronto
# 5       hmm what options would i have out of Toronto?
# 6                                  that would be nice
# 7   No sorry i was planning on getting a tan this ...
# 8          What options do you have available for me?
# 9   That sounds interesting. how many stars does t...
# 10                           Ahh...maybe another time
#
#                                                Answer
# 0   when  would you like to travel and how many pe...
# 1                               do you have a budget?
# 2                  where will you be travelling from?
# 3   We have nothing available leaving from Neverla...
# 4   Gotham City is not a destination we travel to....
# 5                 Would you be interested in Calgary?
# 6   I have a departure from Toronto to Calgary  on...
# 7   How about a trip to Dominican Republic? it is ...
# 8   I have the el Mar hotel available in Punta Can...
# 9   2.5 stars. You would have to fly out of Melbou...
# 10                                                NaN

# %%
qna[0].values
# Out:
#                                             Question  \
# 0  I'd like to book a trip to Atlantis from Capri...
# 1  Yes, how about going to Neverland from Caprica...
# 2  I have no flexibility for dates... but I can l...
# 3  I suppose I'll speak with my husband to see if...
#
#                                               Answer
# 0  Hi...I checked a few options for you, and unfo...
# 1  I checked the availability for this date and t...
# 2  I checked the availability for that date and t...
# 3                                                NaN

# %%
def export_qnaDTO(qna):
    return QnADTO(
        answer=qna[1],
        questions=[qna[0]],
        metadata=[
            MetadataDTO(name="Category", value="api"),
            MetadataDTO(name="Language", value="Python"),
        ]
    )

qna_list = [export_qnaDTO(qna) for qna in qna[0].values]

# %%
def create_kb(client, qna_list, name='New QNA'):
    print ("Creating knowledge base...")

    urls = []

    create_kb_dto = CreateKbDTO(
        name=name,
        qna_list=qna_list,
        urls=urls,
        files=[],
        enable_hierarchical_extraction=True,
        default_answer_used_for_extraction="No answer found.",
        language="English"
    )
    create_op = client.knowledgebase.create(create_kb_payload=create_kb_dto)

    create_op_monitor = _monitor_operation(client=client, operation=create_op)

    # Get knowledge base ID from resourceLocation HTTP header
    knowledge_base_ID = create_op_monitor.resource_location.replace("/knowledgebases/", "")
    print("Created KB with ID: {}".format(knowledge_base_ID))

    return knowledge_base_ID

kb_id = create_kb(client, qna_list)
kb_id
# Out:
# Creating knowledge base...
# Waiting for operation: aabe3c40-5a97-42cb-9c65-37e6b6d4865b to complete.
# Created KB with ID: 746a8b49-3d96-492b-9ba7-b5cb30de7309
# '746a8b49-3d96-492b-9ba7-b5cb30de7309'

# %%
def update_kb(client, kb_id, qna_list):
    print ("Updating knowledge base...")

    urls = [
        "https://docs.microsoft.com/azure/cognitive-services/QnAMaker/troubleshooting"
    ]

    update_kb_operation_dto = UpdateKbOperationDTO(
        add=UpdateKbOperationDTOAdd(
            qna_list=qna_list,
            urls = urls,
            files=[]
        ),
        delete=None,
        update=None
    )
    update_op = client.knowledgebase.update(kb_id=kb_id, update_kb=update_kb_operation_dto)
    _monitor_operation(client=client, operation=update_op)
    print("Updated knowledge base.")

# %%
# Envoi de l'ensemble des questions/réponses

kb_id = '746a8b49-3d96-492b-9ba7-b5cb30de7309'

[update_kb(client, kb_id, [export_qnaDTO(qna__) for qna__ in qna_.values]) for qna_ in qna[1:]]
# Out:
# Updating knowledge base...
# Waiting for operation: 82da0306-8814-4a99-a025-8c8b60fc51fa to complete.
# Waiting for operation: 82da0306-8814-4a99-a025-8c8b60fc51fa to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: 68456b41-26f7-49d3-b0f3-4d09507bfd62 to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: 70e5caba-f82d-433e-818a-4de1efcf1551 to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: e6576865-814e-4e42-ba67-974043fdd264 to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: 5915abba-5ec2-4a49-a6dd-c6cbd62a5f4c to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: 26a54942-687d-4a22-9c7f-7a1164384dad to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: 7ebffe8d-0ee9-4eb0-80a5-584e192ec4cb to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: d1e672be-076d-4548-a107-eda1512b7279 to complete.
# Updated knowledge base.
# Updating knowledge base...
# Waiting for operation: c908a79d-d17b-44ce-8098-d96d4b2672c5 to complete.
# Updated knowledge base.
# [None, None, None, None, None, None, None, None, None]

# %%
# Publication

def publish_kb(client, kb_id):
    print("Publishing knowledge base...")
    client.knowledgebase.publish(kb_id=kb_id)
    print("Published knowledge base.")

# %%
publish_kb(client, kb_id)
# Out:
# Publishing knowledge base...
# Published knowledge base.

# %%
def getEndpointKeys_kb(client):
    print("Getting runtime endpoint keys...")
    keys = client.endpoint_keys.get_keys()
    print("Primary runtime endpoint key: {}.".format(keys.primary_endpoint_key))

    return keys.primary_endpoint_key

queryRuntimeKey = getEndpointKeys_kb(client)

runtimeClient = QnAMakerRuntimeClient(runtime_endpoint=runtime_endpoint, 
                                      credentials=CognitiveServicesCredentials(queryRuntimeKey))



def generate_answer(client, kb_id, runtimeKey):
    print ("Querying knowledge base...")

    authHeaderValue = "EndpointKey " + runtimeKey

    listSearchResults = client.runtime.generate_answer(kb_id, 
                                                       QueryDTO(question = "How do I manage my knowledgebase?"), 
                                                       dict(Authorization=authHeaderValue))

    for i in listSearchResults.answers:
        print(f"Answer ID: {i.id}.")
        print(f"Answer: {i.answer}.")
        print(f"Answer score: {i.score}.")
# Out:
# Getting runtime endpoint keys...
# Primary runtime endpoint key: a9399771-d190-42c3-a598-bc1aeaa405ea.

# %%
generate_answer(runtimeClient, kb_id, queryRuntimeKey)
# Out:
# Querying knowledge base...
# Answer ID: 6.
# Answer: **Answer**:QnAMaker service endpoint is useful for debugging purposes when you contact QnAMaker Support or UserVoice. The endpoint is a URL in this form: `https://your-resource-name.azurewebsites.net`.
#
# 1.  Go to your QnAMaker service (resource group) in the [Azure portal](https://portal.azure.com)
# ![QnAMaker Azure resource group in Azure portal](https://docs.microsoft.com/azure/cognitive-services/QnAMaker/media/qnamaker-how-to-troubleshoot/qnamaker-azure-resourcegroup.png)
# 2.  Select the App Service associated with the QnA Maker resource. Typically, the names are the same.
# ![Select QnAMaker App Service](https://docs.microsoft.com/azure/cognitive-services/QnAMaker/media/qnamaker-how-to-troubleshoot/qnamaker-azure-appservice.png)
# 3.  The endpoint URL is available in the Overview section
# ![QnAMaker endpoint](https://docs.microsoft.com/azure/cognitive-services/QnAMaker/media/qnamaker-how-to-troubleshoot/qnamaker-azure-gethostname.png)
#
# ## Manage the knowledge base.
# Answer score: 38.28.

# %%
POST /knowledgebases/746a8b49-3d96-492b-9ba7-b5cb30de7309/generateAnswer
Host: https://qna0.azurewebsites.net/qnamaker
Authorization: EndpointKey a9399771-d190-42c3-a598-bc1aeaa405ea
Content-Type: application/json
{"question":"<Your question>"}

# %%
class DefaultConfig:
    """ Bot Configuration """
    PORT = 3978
    APP_ID = os.environ.get("MicrosoftAppId", "")
    APP_PASSWORD = os.environ.get("MicrosoftAppPassword", "")

    QNA_KNOWLEDGEBASE_ID = os.environ.get("QnAKnowledgebaseId", "746a8b49-3d96-492b-9ba7-b5cb30de7309")
    QNA_ENDPOINT_KEY = os.environ.get("QnAEndpointKey", "a9399771-d190-42c3-a598-bc1aeaa405ea")
    QNA_ENDPOINT_HOST = os.environ.get("QnAEndpointHostName", "https://qna0.azurewebsites.net/qnamaker")
